# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from img_to_traj import image_to_traj
i=0
N=10
frame=cv2.imread('Exp1_123/Rec_iLQR/1000.jpg')
i2t=image_to_traj(N=10)
[crops,cxs,cys,hh]=i2t.run(frame)
#crops,cxs,cys=get_points(segment,N)
for x,y,crop in zip(cxs,cys,crops):
    img = cv2.circle(frame,(x,i+y), 2, (255,255,255), -1)
    print('x,y :',x,y+i,end=' ')
    i+=N
    
plt.imshow(img,cmap='gray',vmin=0,vmax=255)
plt.show()
# Out:
# x,y : 65 4 x,y : 58 13 x,y : 46 23 x,y : 43 35 x,y : 51 44 x,y : 48 54 x,y : 47 60 x,y : 47 70 x,y : 47 80
