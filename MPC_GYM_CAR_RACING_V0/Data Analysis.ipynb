# %%
import cv2

# %%
img=cv2.imread('Rec_iLQR_Raw/1.jpg',0)

# %%
cv2.imshow('img',img)
cv2.waitKey(0)

# %%
import pickle
f=open('Exp1_123/dataset_iLQR','rb')
dataset=pickle.load(f)
f.close()

# %%
dataset.keys()
# Out:
# dict_keys(['state', 'traj', 'image', 'action', 'next_sate', 'time_reward'])

# %%
import numpy as np
state=np.array(dataset['traj'])
n_state=np.array(dataset['next_sate'])
traj=np.array(dataset['traj'])

# %%
from matplotlib import pyplot as plt
plt.plot(traj[0:200,0,0])
plt.show()
