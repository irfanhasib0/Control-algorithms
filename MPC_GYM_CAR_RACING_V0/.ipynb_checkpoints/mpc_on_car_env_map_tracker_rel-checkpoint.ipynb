# %%
# %matplotlib tk
import matplotlib.pyplot as plt
import cvxpy
import math
import numpy as np
#import cubic_spline_planner


NX = 4  # x = x, y, v, yaw
NU = 2  # a = [accel, steer]
T = 5  # horizon length

# mpc parameters
R = np.diag([0.01, 0.01])  # input cost matrix
Rd = np.diag([0.01, 1.0])  # input difference cost matrix
Q = np.diag([1.0, 1.0, 0.5, 0.5])  # state cost matrix
Qf = Q  # state final matrix

GOAL_DIS = 1.5  # goal distance
STOP_SPEED = 0.5 / 3.6  # stop speed
MAX_TIME = 500.0  # max simulation time

# iterative paramter
MAX_ITER = 3  # Max iteration
DU_TH = 0.1  # iteration finish param

TARGET_SPEED = 15#10.0 / 3.6  # [m/s] target speed
N_IND_SEARCH = 10  # Search index number

DT = 0.2  # [s] time tick

# Vehicle parameters
WB = 110#2.5  # [m]

MAX_STEER = np.deg2rad(45.0)  # maximum steering angle [rad]
MAX_DSTEER = np.deg2rad(30.0)  # maximum steering speed [rad/s]
MAX_SPEED = 25#55.0 / 3.6  # maximum speed [m/s]
MIN_SPEED = -25#-20.0 / 3.6  # minimum speed [m/s]
MAX_ACCEL = 5.0  # maximum accel [m/ss]

show_animation = True

# %%
def iterative_linear_mpc_control(xref, Motion_Status, dref, oa, od):
    """
    MPC contorl with updating operational point iteraitvely
    """  
    
    if oa is None or od is None:
        oa = [0.0] * T
        od = [0.0] * T
    state=Motion_Status.get_state()   
    for i in range(MAX_ITER):
        xbar = Motion_Status.get_trajectory(oa, od,T)
        poa, pod = oa[:], od[:]
        oa, od, ox, oy, oyaw, ov = linear_mpc_control(xref, xbar, state, dref)
        du = sum(abs(oa - poa)) + sum(abs(od - pod))  # calc u change value
        if du <= DU_TH:
            break
    else:
        print("Iterative is max iter")
    
    return oa, od, ox, oy, oyaw, ov,xbar

def get_linear_model_matrix(v, phi, delta):

    A = np.zeros((NX, NX))
    A[0, 0] = 1.0
    A[1, 1] = 1.0
    A[2, 2] = 1.0
    A[3, 3] = 1.0
    A[0, 2] = DT * math.cos(phi)
    A[0, 3] = - DT * v * math.sin(phi)#
    A[1, 2] = DT * math.sin(phi)
    A[1, 3] = DT * v * math.cos(phi)#
    A[3, 2] = DT * math.tan(delta) / WB

    B = np.zeros((NX, NU))
    B[2, 0] = DT
    B[3, 1] = DT * v / (WB * math.cos(delta) ** 2)#

    C = np.zeros(NX)
    C[0] = DT * v * math.sin(phi) * phi
    C[1] = - DT * v * math.cos(phi) * phi
    C[3] = - DT * v * delta / (WB * math.cos(delta) ** 2)
    #C = np.zeros(NX)
    return A, B, C

def linear_mpc_control(xref, xbar, state, dref):
    """
    linear mpc control

    xref: reference point
    xbar: operational point
    x0: initial state
    dref: reference steer angle
    """

    x = cvxpy.Variable((NX, T + 1))
    u = cvxpy.Variable((NU, T))

    cost = 0.0
    constraints = []

    for t in range(T):
        cost += cvxpy.quad_form(u[:, t], R)

        if t != 0:
            cost += cvxpy.quad_form(xref[:, t] - x[:, t], Q)

        A, B, C = get_linear_model_matrix(xbar[2, t], xbar[3, t], 0)
        constraints += [x[:, t + 1] == A * x[:, t] + B * u[:, t]+ C]

        if t < (T - 1):
            cost += cvxpy.quad_form(u[:, t + 1] - u[:, t], Rd)
            constraints += [cvxpy.abs(u[1, t + 1] - u[1, t]) <=
                            MAX_DSTEER * DT]

    cost += cvxpy.quad_form(xref[:, T] - x[:, T], Qf)

    constraints += [x[:, 0] == [state.x,state.y,state.v,state.yaw]]
    constraints += [x[2, :] <= MAX_SPEED]
    constraints += [x[2, :] >= MIN_SPEED]
    constraints += [cvxpy.abs(u[0, :]) <= MAX_ACCEL]
    constraints += [cvxpy.abs(u[1, :]) <= MAX_STEER]

    prob = cvxpy.Problem(cvxpy.Minimize(cost), constraints)
    prob.solve(solver=cvxpy.OSQP, warm_start=True)
    #prob.solve(solver=cvxpy.ECOS, verbose=False)

    if prob.status == cvxpy.OPTIMAL or prob.status == cvxpy.OPTIMAL_INACCURATE:
        ox = np.array(x.value[0, :]).flatten()
        oy = np.array(x.value[1, :]).flatten()
        ov = np.array(x.value[2, :]).flatten()
        oyaw = np.array(x.value[3, :]).flatten()
        oa = np.array(u.value[0, :]).flatten()
        odelta = np.array(u.value[1, :]).flatten()

    else:
        print("Error: Cannot solve mpc..")
        oa, odelta, ox, oy, oyaw, ov = None, None, None, None, None, None

    return oa, odelta, ox, oy, oyaw, ov

# %%
class State:
     
    def __init__(self, x=0.0, y=0.0, yaw=0.0, v=0.0):
        self.x = x
        self.y = y
        self.yaw = yaw
        self.v = v
        self.predelta = None

class Motion():

    def __init__(self, x=0.0, y=0.0, yaw=0.0, v=0.0):
        self.state=State(x=x, y=y, yaw=yaw, v=v)
        
    def get_state(self):
        return State(x=self.state.x, y=self.state.y, yaw=self.state.yaw, v=self.state.v)
        
    def set_state(self,state):
        self.state=state
    def get_next_state(self, a, delta, curr_state=-1):
        if curr_state==-1:
            curr_state=self.state
        # input check
        if delta >= MAX_STEER:
            delta = MAX_STEER
        elif delta <= -MAX_STEER:
            delta = -MAX_STEER

        next_x = curr_state.x + curr_state.v * math.cos(curr_state.yaw) * DT
        next_y = curr_state.y + curr_state.v * math.sin(curr_state.yaw) * DT
        next_yaw = curr_state.yaw + curr_state.v / WB * math.tan(delta) * DT
        next_v = curr_state.v + a * DT
        
        if next_v > MAX_SPEED:
            next_v = MAX_SPEED
        elif next_v < MIN_SPEED:
            next_v = MIN_SPEED

        return State(x=next_x,y=next_y,v=next_v,yaw=next_yaw)


    def get_trajectory(self,accels, deltas,time_step):
        xbar =np.zeros((NX, time_step + 1))
        xbar[:, 0] = self.state.x,self.state.y,self.state.v,self.state.yaw
        #_state=State(x=state.x,y=state.y,v=state.v,yaw=state.yaw)
        _state=Motion.get_state(self)
        for (accel, delta, i) in zip(accels, deltas, range(1, T + 1)):
            next_state = Motion.get_next_state(self,accel, delta, curr_state=_state)
            xbar[:, i] = next_state.x,next_state.y,next_state.v,next_state.yaw
            _state=next_state
        

        return xbar

# %%
from Car_Env import Car_Env
from Data_Processor import Data_Processor
from Car_Plot import Move_Contour,Draw_Car

# %%
#cx, cy, cyaw, ck = get_switch_back_course(dl)
dl=1.0
rec=True
max_len=350
qlen=25
car_move=True
Env=Car_Env(rec=rec,max_len=max_len,qlen=qlen)
[init_state,map_points]=Env.reset()
mpx=np.array(map_points[:max_len,0])#-ofx
mpy=np.array(map_points[:max_len,1])#-ofy
ix,iy,iyaw,ivel=init_state[0]
_traj=init_state[1][0]
_dind=init_state[1][1]
_end=init_state[1][2]
ofx,ofy,ofang=init_state[2]
img=init_state[3]
Motion_Status = Motion(x=ix, y=iy, yaw=iyaw, v=ivel)
state=Motion_Status.get_state()
#print(init_state)
# Out:
# Track generation: 1211..1518 -> 307-tiles track

# %%
if rec==True:
    import os
    if not os.path.exists('Rec/'):
        os.mkdir('Rec')
    if not os.path.exists('Fig/'):
        os.mkdir('Fig')

# %%
import matplotlib.gridspec as gridspec
phi=0
rot_mat=np.array([[math.cos(phi),math.sin(phi)],[-math.sin(phi),math.cos(phi)]])
time = 0.0
x = [state.x]
y = [state.y]
yaw = [state.yaw]
v = [state.v]
t = [0.0]
d = [0.0]
a = [0.0]

log_state=[]
log_traj=[]
log_img=[]
log_act=[]
log_next_state=[]


#index, _ = get_closest_point(state, _cx, _cy, cyaw, 0)
odelta, oa = None, None
_index=0
#cyaw = smooth_yaw(cyaw)
accl,gas,steer=0,0,0
state_str=''
act_str=''
xref_str=''
xbar_str=''


_Data_Processor=Data_Processor(_speed=TARGET_SPEED,tlen=qlen)
acc_st=State(x=0,y=0)
itr=0
#fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(10,10))
fig=plt.figure(figsize=(10,10))
gs = fig.add_gridspec(3, 1)
ax1=fig.add_subplot(gs[0,:])
ax2=fig.add_subplot(gs[1:,:])
axes=[ax1,ax2]


def map_plot(vect,_ofx,_ofy,_ofang):
    _vect=np.array(vect,dtype=np.float64).copy()
    _ofang=-1*_ofang
    rot_mat=np.array([[math.cos(_ofang),math.sin(_ofang)],[-math.sin(_ofang),math.cos(_ofang)]])
    _vect=np.matmul(rot_mat,_vect)

    _vect[0]+=_ofx
    _vect[1]+=_ofy
    return [_vect[0],_vect[1]]
def inv_map_plot(vect,_ofx,_ofy,_ofang):
    _vect=np.array(vect,dtype=np.float64).copy()
    _vect[0]-=_ofx
    _vect[1]-=_ofy
    _ofang=1*_ofang
    rot_mat=np.array([[math.cos(_ofang),math.sin(_ofang)],[-math.sin(_ofang),math.cos(_ofang)]])
    _vect=np.matmul(rot_mat,_vect)
    return [_vect[0],_vect[1]]

while MAX_TIME >= time:
        state=Motion_Status.get_state()
        _full_state = [state.x, state.y, state.v, state.yaw]
    
        
        _full_state_traj=_Data_Processor.update_trajectory(_traj)
        xref, dref = _Data_Processor.get_ref_trajectory(state,dl,DT,T)
        
        if _end==True:
            break

        _index+=_dind
        
        oa, odelta, ox, oy, oyaw, ov ,xbar= iterative_linear_mpc_control(xref, Motion_Status, dref, oa, odelta)
        
        state_str=str(state.x)+','+str(state.y)+','+str(state.v)+','+str(np.rad2deg(state.yaw))+'\n'
        xref_str=str(xref[0][0])+','+str(xref[1][0])+','+str(xref[2][0])+','+str(np.rad2deg(xref[3][0]))+','+str(_index)+'\n'
        xbar_str=str(xbar[0][0])+','+str(xbar[1][0])+','+str(xbar[2][0])+','+str(np.rad2deg(xbar[3][0]))+'\n'
        act_str=str(accl)+','+str(gas)+','+str(np.rad2deg(steer))+'\n'
    
        #xref_str=str(xref[3][0])+'\n'
        #xbar_str=str(xbar[3][:])+'\n'
        if odelta is not None:
            di, ai = odelta[0], oa[0]
        accl=ai
        steer=di
        
        #act_str=str(steer)+'\n'
        nst,path,offset,img,rw,ter,info=Env.step([steer,accl,0])
        _traj,_dind,_end=path
        ofx,ofy,ofang=offset
        
        gas=Env.gas
        
        next_state=State(x=nst[0],y=nst[1],yaw=nst[2],v=nst[3])
        Motion_Status.set_state(next_state)
        
        log_state.append(_full_state)
        log_traj.append(_full_state_traj)
        log_img.append(img)
        log_act.append([accl,steer,0])
        log_next_state.append(next_state)
        
        time = time + DT
        if car_move==True:
            _xref=xref.copy()
            [_ox,_oy]=map_plot([ox,oy],ofx,ofy,ofang)
            [_xref[0,:],_xref[1,:]]=map_plot([xref[0,:],xref[1,:]],ofx,ofy,ofang)
            [_x,_y]=map_plot([state.x,state.y],ofx,ofy,ofang)
            car_x,car_y,car_ang=ofx,ofy,ofang
            _mpx,_mpy=mpx,mpy
        else:
            _ox,_oy=ox,oy
            _xref=xref
            _x,_y=state.x,state.y
            car_x,car_y,car_ang=state.x,state.y,state.yaw
            [_mpx,_mpy]=inv_map_plot([mpx,mpy],ofx,ofy,ofang)
        x.append(_x)
        y.append(_y)
        yaw.append(ofang)
        v.append(state.v)
        t.append(time)
        d.append(di)
        a.append(ai)

        
    
      
        
        if show_animation:  # pragma: no cover
            axes[0].cla()
            axes[1].cla()
            axes[0].text(.01,.6,'state : '+state_str,fontsize=10,color='r')
            axes[0].text(.01,.4,'xref : '+xref_str,fontsize=10,color='b')
            axes[0].text(.01,.2,'xbar : '+xbar_str,fontsize=10,color='c')
            axes[0].text(.01,0,'act : '+act_str,fontsize=10,color='g')
            
            if ox is not None:
                axes[1].plot(_ox, _oy, "xr", label="MPC",alpha=1.0)
            axes[1].plot(_mpx, _mpy, "-b", label="course")
            axes[1].plot(x, y, "oc", label="trajectory")
            axes[1].plot(_xref[0, :], _xref[1, :], "xk", label="xref",alpha=1.0)
            axes[1].plot(_mpx[_index], _mpy[_index], "xg", label="target",alpha=1.0)
            #plot_car(state.x, state.y, state.yaw, steer=di)
            
            car_points=Draw_Car(car_x,car_y)
            rp=Move_Contour(car_points,0,0,car_ang)
            r_car_points=rp.apply()
            r_points=np.array(r_car_points,dtype=np.float64)
            axes[1].plot(r_points[:,0].flatten(),r_points[:,1].flatten(),"-r")
            
            plt.axis("equal")
            plt.grid(True)
            #plt.title("Time[s]:" + str(round(time, 2))
            #          + ", speed[km/h]:" + str(round(state.v * 3.6, 2))
            #          + '\nyaw'+str(state.yaw)
            #          + '\nxref_yaw'+str(xref[3][0])
            #          + '\nsteer'+str(steer))
            #fig.canvas.draw()
            plt.pause(0.0001)
            if itr%25==0:
                plt.savefig('Fig/'+str(int(itr/25))+'.jpg')
            itr+=1
if show_animation:  # pragma: no cover
            plt.close("all")
            plt.subplots()
            plt.plot(cx, cy, "-r", label="spline")
            plt.plot(x, y, "-g", label="tracking")
            plt.grid(True)
            plt.axis("equal")
            plt.xlabel("x[m]")
            plt.ylabel("y[m]")
            plt.legend()

            plt.subplots()
            plt.plot(t, v, "-r", label="speed")
            plt.grid(True)
            plt.xlabel("Time [s]")
            plt.ylabel("Speed [kmh]")

            plt.show()
# Out:
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# Iterative is max iter
# ---------------------------------------------------------------------------
# ResetNeeded                               Traceback (most recent call last)
# <ipython-input-7-1b40dc6c13a7> in <module>
#      86
#      87         #act_str=str(steer)+'\n'
# ---> 88         nst,path,offset,img,rw,ter,info=Env.step([steer,accl,0])
#      89         _traj,_dind,_end=path
#      90         ofx,ofy,ofang=offset
#
# ~/Desktop/Control-algorithms/MPC_GYM_CAR_RACING_V0/Car_Env.py in step(self, action, show_plot)
#      72         self.brake=action[2]
#      73
# ---> 74         nst,rw,ter,info=self.ENV.step(action) # take a random action
#      75         self.frame[0:96,0:96,:]=np.array(nst)
#      76
#
# ~/.local/lib/python3.6/site-packages/gym/wrappers/monitor.py in step(self, action)
#      28
#      29     def step(self, action):
# ---> 30         self._before_step(action)
#      31         observation, reward, done, info = self.env.step(action)
#      32         done = self._after_step(observation, reward, done, info)
#
# ~/.local/lib/python3.6/site-packages/gym/wrappers/monitor.py in _before_step(self, action)
#     158     def _before_step(self, action):
#     159         if not self.enabled: return
# --> 160         self.stats_recorder.before_step(action)
#     161
#     162     def _after_step(self, observation, reward, done, info):
#
# ~/.local/lib/python3.6/site-packages/gym/wrappers/monitoring/stats_recorder.py in before_step(self, action)
#      44
#      45         if self.done:
# ---> 46             raise error.ResetNeeded("Trying to step environment which is currently done. While the monitor is active for {}, you cannot step beyond the end of an episode. Call 'env.reset()' to start the next episode.".format(self.env_id))
#      47         elif self.steps is None:
#      48             raise error.ResetNeeded("Trying to step an environment before reset. While the monitor is active for {}, you must call 'env.reset()' before taking an initial step.".format(self.env_id))
#
# ResetNeeded: Trying to step environment which is currently done. While the monitor is active for CarRacing-v0, you cannot step beyond the end of an episode. Call 'env.reset()' to start the next episode.

# %%
log_dict={
'state':log_state,
'traj':log_traj,
'image':log_img,
'action':log_act,
'next_sate':log_next_state
}

# %% [raw]
# import pickle
# f=open('dataset','wb')
# pickle.dump(log_dict,f)
# f.close()
# itr

# %%
f=open('dataset','rb')
dataset=pickle.load(f)
f.close()

# %%
dataset
# Out:
# {'state': [[0, 0, 8.338805894756252e-07, 0],
#   [0, 0, 0.17965380514180146, 0],
#   [0, 0, 0.31865975907267957, 0],
#   [0, 0, 0.4607369543163854, 0],
#   [0, 0, 0.5998454755857563, 0],
#   [0, 0, 0.7380933245466544, 0],
#   [0, 0, 0.8756686684955219, 0],
#   [0, 0, 1.0128781472451251, 0],
#   [0, 0, 1.1498530725283398, 0],
#   [0, 0, 1.2867470363233866, 0],
#   [0, 0, 1.423728316412636, 0],
#   [0, 0, 1.561023077423761, 0],
#   [0, 0, 1.6989046306137934, 0],
#   [0, 0, 1.8376649821634585, 0],
#   [0, 0, 1.9775692447767685, 0],
#   [0, 0, 2.118794456631642, 0],
#   [0, 0, 2.2608709773823605, 0],
#   [0, 0, 2.404381410816792, 0],
#   [0, 0, 2.5491493429531937, 0],
#   [0, 0, 2.694684925232067, 0],
#   [0, 0, 2.8407334162832707, 0],
#   [0, 0, 2.9869997219512583, 0],
#   [0, 0, 3.1333230351628902, 0],
#   [0, 0, 3.2796707752123417, 0],
#   [0, 0, 3.4258742662041044, 0],
#   [0, 0, 3.5725610120926077, 0],
#   [0, 0, 3.719570733452919, 0],
#   [0, 0, 3.8668746111545995, 0],
#   [0, 0, 4.014521250547823, 0],
#   [0, 0, 4.16257308751612, 0],
#   [0, 0, 4.308570873933274, 0],
#   [0, 0, 4.456940371683594, 0],
#   [0, 0, 4.602595349153551, 0],
#   [0, 0, 4.753058205359535, 0],
#   [0, 0, 4.902073957778117, 0],
#   [0, 0, 5.051303638956469, 0],
#   [0, 0, 5.200917427321915, 0],
#   [0, 0, 5.350300704961976, 0],
#   [0, 0, 5.500515369695319, 0],
#   [0, 0, 5.650567886071663, 0],
#   [0, 0, 5.800571880087305, 0],
#   [0, 0, 5.951108496654881, 0],
#   [0, 0, 6.1015057950591265, 0],
#   [0, 0, 6.251724640368886, 0],
#   [0, 0, 6.402708599468682, 0],
#   [0, 0, 6.553086169954841, 0],
#   [0, 0, 6.704004652882336, 0],
#   [0, 0, 6.855256599519506, 0],
#   [0, 0, 7.005807408771799, 0],
#   [0, 0, 7.1578586751521165, 0],
#   [0, 0, 7.308231612707543, 0],
#   [0, 0, 7.4607430512272, 0],
#   [0, 0, 7.611542286040898, 0],
#   [0, 0, 7.7642449722277815, 0],
#   [0, 0, 7.915590512719717, 0],
#   [0, 0, 8.068705788035182, 0],
#   [0, 0, 8.220270762922523, 0],
#   [0, 0, 8.37384599398414, 0],
#   [0, 0, 8.526008402134416, 0],
#   [0, 0, 8.677883777217883, 0],
#   [0, 0, 8.830821855015012, 0],
#   [0, 0, 8.981655064890486, 0],
#   [0, 0, 9.135097664830088, 0],
#   [0, 0, 9.288718219364101, 0],
#   [0, 0, 9.440146848578383, 0],
#   [0, 0, 9.595469057226603, 0],
#   [0, 0, 9.748243746264773, 0],
#   [0, 0, 9.902153093182589, 0],
#   [0, 0, 10.055714118291778, 0],
#   [0, 0, 10.208783346025399, 0],
#   [0, 0, 10.363983944368961, 0],
#   [0, 0, 10.51699470542674, 0],
#   [0, 0, 10.671949113295886, 0],
#   [0, 0, 10.826464692278508, 0],
#   [0, 0, 10.980090778246748, 0],
#   [0, 0, 11.135097573020294, 0],
#   [0, 0, 11.289829020095356, 0],
#   [0, 0, 11.436836599947027, 0],
#   [0, 0, 11.591587767953689, 0],
#   [0, 0, 11.750453412259782, 0],
#   [0, 0, 11.897393939864319, 0],
#   [0, 0, 12.046764077984882, 0],
#   [0, 0, 12.208529555419481, 0],
#   [0, 0, 12.3600332544635, 0],
#   [0, 0, 12.50074700343969, 0],
#   [0, 0, 12.661210167662382, 0],
#   [0, 0, 12.820219460534759, 0],
#   [0, 0, 12.966677157232128, 0],
#   [0, 0, 13.102611247880679, 0],
#   [0, 0, 13.26820693441183, 0],
#   [0, 0, 13.428764600951107, 0],
#   [0, 0, 13.576899686916006, 0],
#   [0, 0, 13.711635365387115, 0],
#   [0, 0, 13.843163893956254, 0],
#   [0, 0, 14.01452214786289, 0],
#   [0, 0, 14.18164235562896, 0],
#   [0, 0, 14.336650694953903, 0],
#   [0, 0, 14.47924643137498, 0],
#   [0, 0, 14.606059064317876, 0],
#   [0, 0, 14.68203099885933, 0],
#   [0, 0, 14.784905656572839, 0],
#   [0, 0, 14.852134072425713, 0],
#   [0, 0, 15.038742004994061, 0],
#   [0, 0, 15.189479061249534, 0],
#   [0, 0, 15.329670606940189, 0],
#   [0, 0, 15.451178153790018, 0],
#   [0, 0, 15.5497653628418, 0],
#   [0, 0, 15.575372566861965, 0],
#   [0, 0, 15.673065735099106, 0],
#   [0, 0, 15.74045351944469, 0],
#   [0, 0, 15.761697382827085, 0],
#   [0, 0, 15.776076650526349, 0],
#   [0, 0, 15.776272056267137, 0],
#   [0, 0, 15.761089321080918, 0],
#   [0, 0, 15.91942756526504, 0],
#   [0, 0, 16.019117204156416, 0],
#   [0, 0, 16.051578987894068, 0],
#   [0, 0, 16.028976528992185, 0],
#   [0, 0, 15.95850045678967, 0],
#   [0, 0, 16.021658881511136, 0],
#   [0, 0, 16.069375259185957, 0],
#   [0, 0, 16.107268161698595, 0],
#   [0, 0, 16.146230935032076, 0],
#   [0, 0, 16.17273451459897, 0],
#   [0, 0, 16.186858278215624, 0],
#   [0, 0, 16.36280436687407, 0],
#   [0, 0, 16.417626626047607, 0],
#   [0, 0, 16.429637971803505, 0],
#   [0, 0, 16.39158455009927, 0],
#   [0, 0, 16.31302123317207, 0],
#   [0, 0, 16.209168234629537, 0],
#   [0, 0, 16.083120385047003, 0],
#   [0, 0, 15.933393757801435, 0],
#   [0, 0, 15.90653361529441, 0],
#   [0, 0, 15.962516253554597, 0],
#   [0, 0, 16.016337316918825, 0],
#   [0, 0, 16.266466327294854, 0],
#   [0, 0, 16.409883208616844, 0],
#   [0, 0, 16.50130758888594, 0],
#   [0, 0, 16.538682588464763, 0],
#   [0, 0, 16.550085189241507, 0],
#   [0, 0, 16.546188129985797, 0],
#   [0, 0, 16.522977601697605, 0],
#   [0, 0, 16.479875211318017, 0],
#   [0, 0, 16.415957435695212, 0],
#   [0, 0, 16.33056445634237, 0],
#   [0, 0, 16.400001153611804, 0],
#   [0, 0, 16.364702807019185, 0],
#   [0, 0, 16.39298593949759, 0],
#   [0, 0, 16.403144891026482, 0],
#   [0, 0, 16.382593755168035, 0],
#   [0, 0, 16.349412263287604, 0],
#   [0, 0, 16.405910214470406, 0],
#   [0, 0, 16.4711941149298, 0],
#   [0, 0, 16.52564584389939, 0],
#   [0, 0, 16.575935491344712, 0],
#   [0, 0, 16.612600259959397, 0],
#   [0, 0, 16.755395882062384, 0],
#   [0, 0, 16.795151457019262, 0],
#   [0, 0, 16.791706381768048, 0],
#   [0, 0, 16.756074448163204, 0],
#   [0, 0, 16.70201429774924, 0],
#   [0, 0, 16.625926740011906, 0],
#   [0, 0, 16.527748460439245, 0],
#   [0, 0, 16.406702554511476, 0],
#   [0, 0, 16.262065834929565, 0],
#   [0, 0, 16.201575300551173, 0],
#   [0, 0, 16.158911824204015, 0],
#   [0, 0, 16.301859445055346, 0],
#   [0, 0, 16.367008427722727, 0],
#   [0, 0, 16.49851841927208, 0],
#   [0, 0, 16.591258677530753, 0],
#   [0, 0, 16.645892036583636, 0],
#   [0, 0, 16.703754018030565, 0],
#   [0, 0, 16.747996129833055, 0],
#   [0, 0, 16.77893712799024, 0],
#   [0, 0, 16.79306609281294, 0],
#   [0, 0, 16.788949643630453, 0],
#   [0, 0, 16.76525064817667, 0],
#   [0, 0, 16.78135577773737, 0],
#   [0, 0, 16.730137809003537, 0],
#   [0, 0, 16.644205087163932, 0],
#   [0, 0, 16.5333613091718, 0],
#   [0, 0, 16.39965202992944, 0],
#   [0, 0, 16.34403297833672, 0],
#   [0, 0, 16.305611763907624, 0],
#   [0, 0, 16.26400502436425, 0],
#   [0, 0, 16.233204440459808, 0],
#   [0, 0, 16.204197716417568, 0],
#   [0, 0, 16.236466896000188, 0],
#   [0, 0, 16.470743509556343, 0],
#   [0, 0, 16.588584092252354, 0],
#   [0, 0, 16.66383982210579, 0],
#   [0, 0, 16.702419084842056, 0],
#   [0, 0, 16.731697505851947, 0],
#   [0, 0, 16.743407157753136, 0],
#   [0, 0, 16.736948088151227, 0],
#   [0, 0, 16.71084682592995, 0],
#   [0, 0, 16.664246016948262, 0],
#   [0, 0, 16.596414911526857, 0],
#   [0, 0, 16.580451562396547, 0],
#   [0, 0, 16.50156048478519, 0],
#   [0, 0, 16.391581948980303, 0],
#   [0, 0, 16.35246548741413, 0],
#   [0, 0, 16.312429383243753, 0],
#   [0, 0, 16.268732877453917, 0],
#   [0, 0, 16.236277358502996, 0],
#   [0, 0, 16.20579789972629, 0],
#   [0, 0, 16.180207423078237, 0],
#   [0, 0, 16.15710793099196, 0],
#   [0, 0, 16.225856005274814, 0],
#   [0, 0, 16.421929688575478, 0],
#   [0, 0, 16.375266870479123, 0],
#   [0, 0, 16.45276433002711, 0],
#   [0, 0, 16.524136905178388, 0],
#   [0, 0, 16.570791453909095, 0],
#   [0, 0, 16.61353580416729, 0],
#   [0, 0, 16.637593069659186, 0],
#   [0, 0, 16.645434426642424, 0],
#   [0, 0, 16.634188427960385, 0],
#   [0, 0, 16.60313066274446, 0],
#   [0, 0, 16.551446145688057, 0],
#   [0, 0, 16.47845717152354, 0],
#   [0, 0, 16.383607449765755, 0],
#   [0, 0, 16.409107205212347, 0],
#   [0, 0, 16.448699754210825, 0],
#   [0, 0, 16.473440429780506, 0],
#   [0, 0, 16.495402200736635, 0],
#   [0, 0, 16.50315076214029, 0],
#   [0, 0, 16.496210699997846, 0],
#   [0, 0, 16.471722243968834, 0],
#   [0, 0, 16.428155341992717, 0],
#   [0, 0, 16.364346135469372, 0],
#   [0, 0, 16.279248840530975, 0],
#   [0, 0, 16.172032864824022, 0],
#   [0, 0, 16.041827293507023, 0],
#   [0, 0, 15.989659834017026, 0],
#   [0, 0, 15.953781295374332, 0],
#   [0, 0, 15.914287205233325, 0],
#   [0, 0, 15.885133978006044, 0],
#   [0, 0, 15.857447610846434, 0],
#   [0, 0, 15.83417231873548, 0],
#   [0, 0, 15.921590253497794, 0],
#   [0, 0, 15.826527178278258, 0],
#   [0, 0, 15.791572231774284, 0],
#   [0, 0, 15.876117440841771, 0],
#   [0, 0, 15.942200876896957, 0],
#   [0, 0, 16.00557613644306, 0],
#   [0, 0, 16.058806705655762, 0],
#   [0, 0, 16.09901175673339, 0],
#   [0, 0, 16.157572852620525, 0],
#   [0, 0, 16.1584929704219, 0],
#   [0, 0, 16.14890668158698, 0],
#   [0, 0, 16.118340444135402, 0],
#   [0, 0, 16.067989401645253, 0],
#   [0, 0, 15.996903145509613, 0],
#   [0, 0, 16.093978957431695, 0],
#   [0, 0, 16.222900054398725, 0],
#   [0, 0, 16.327075591181245, 0],
#   [0, 0, 16.37659867857455, 0],
#   [0, 0, 16.393144733282046, 0],
#   [0, 0, 16.401689924775486, 0],
#   [0, 0, 16.394598237398238, 0],
#   [0, 0, 16.3703421851222, 0],
#   [0, 0, 16.32709027632048, 0],
#   [0, 0, 16.447299954445736, 0],
#   [0, 0, 16.45214014964776, 0],
#   [0, 0, 16.415621265437156, 0],
#   [0, 0, 16.329492109961496, 0],
#   [0, 0, 16.30547823806294, 0],
#   [0, 0, 16.272426188081813, 0],
#   [0, 0, 16.293460223547974, 0],
#   [0, 0, 16.355337612868915, 0],
#   [0, 0, 16.410225532673472, 0],
#   [0, 0, 16.46181978361547, 0],
#   [0, 0, 16.685923685276244, 0],
#   [0, 0, 16.78182704406923, 0],
#   [0, 0, 16.831266110177474, 0],
#   [0, 0, 16.826967749453434, 0],
#   [0, 0, 16.801476498884757, 0],
#   [0, 0, 16.755905266052128, 0],
#   [0, 0, 16.689011621147568, 0],
#   [0, 0, 16.600171878492993, 0],
#   [0, 0, 16.48871790017644, 0],
#   [0, 0, 16.353930634389634, 0],
#   [0, 0, 16.48510894390456, 0],
#   [0, 0, 16.64904526725531, 0],
#   [0, 0, 16.766735090100017, 0],
#   [0, 0, 16.838476905937963, 0],
#   [0, 0, 16.88007308732392, 0],
#   [0, 0, 16.916377641427175, 0],
#   [0, 0, 16.938518337349706, 0],
#   [0, 0, 16.944562300117955, 0],
#   [0, 0, 16.932401909044177, 0],
#   [0, 0, 16.900615207150526, 0],
#   [0, 0, 16.84813241451627, 0],
#   [0, 0, 16.85709516815108, 0],
#   [0, 0, 16.794976100467466, 0],
#   [0, 0, 16.698733121550482, 0],
#   [0, 0, 16.565894931173844, 0],
#   [0, 0, 16.51057090565515, 0],
#   [0, 0, 16.46640372437974, 0],
#   [0, 0, 16.4203885787315, 0],
#   [0, 0, 16.38566056796478, 0],
#   [0, 0, 16.352996233618125, 0],
#   [0, 0, 16.419696691927864, 0],
#   [0, 0, 16.492953608204886, 0],
#   [0, 0, 16.709321414007732, 0],
#   [0, 0, 16.814571406450625, 0],
#   [0, 0, 16.87167774963752, 0],
#   [0, 0, 16.899206835716317, 0],
#   [0, 0, 16.912605710333587, 0],
#   [0, 0, 16.90678777371107, 0],
#   [0, 0, 16.881192601619766, 0],
#   [0, 0, 16.834800947223282, 0],
#   [0, 0, 16.76694759784897, 0],
#   [0, 0, 16.677009267151234, 0],
#   [0, 0, 16.69344974164259, 0],
#   [0, 0, 16.625357797729176, 0],
#   [0, 0, 16.626505040477582, 0],
#   [0, 0, 16.615333283450582, 0],
#   [0, 0, 16.57655728810598, 0],
#   [0, 0, 16.540981550841817, 0],
#   [0, 0, 16.599614060869754, 0],
#   [0, 0, 16.66686746418754, 0],
#   [0, 0, 16.72317557325251, 0],
#   [0, 0, 16.77545254612511, 0],
#   [0, 0, 16.813990895257408, 0],
#   [0, 0, 16.927809981710457, 0],
#   [0, 0, 16.950415540455165, 0],
#   [0, 0, 16.935110088564873, 0],
#   [0, 0, 16.90350266131258, 0],
#   [0, 0, 16.85018372714396, 0],
#   [0, 0, 16.775335967539313, 0],
#   [0, 0, 16.678131177384714, 0],
#   [0, 0, 16.557948440164083, 0],
#   [0, 0, 16.45589254775444, 0],
#   [0, 0, 16.351036675920252, 0],
#   [0, 0, 16.314705199671405, 0],
#   [0, 0, 16.441377964699186, 0],
#   [0, 0, 16.488393101585256, 0],
#   [0, 0, 16.51002762103316, 0],
#   [0, 0, 16.59996363884062, 0],
#   [0, 0, 16.66607343559633, 0],
#   [0, 0, 16.72816433328782, 0],
#   [0, 0, 16.78560926515504, 0],
#   [0, 0, 16.8299182200977, 0],
#   [0, 0, 16.860029238822495, 0],
#   [0, 0, 16.872920244442014, 0],
#   [0, 0, 16.86721228080064, 0],
#   [0, 0, 16.889460624355785, 0],
#   [0, 0, 16.84525153346533, 0],
#   [0, 0, 16.77693258704782, 0],
#   [0, 0, 16.686961557267235, 0],
#   [0, 0, 16.57418645321403, 0],
#   [0, 0, 16.437994646956582, 0],
#   [0, 0, 16.381316528285677, 0],
#   [0, 0, 16.342003266306648, 0],
#   [0, 0, 16.29948712691541, 0],
#   [0, 0, 16.267934642633737, 0],
#   [0, 0, 16.42878501491307, 0],
#   [0, 0, 16.589876024147255, 0],
#   [0, 0, 16.71076834959734, 0],
#   [0, 0, 16.775320440262217, 0],
#   [0, 0, 16.826217817930264, 0],
#   [0, 0, 16.865303548991584, 0],
#   [0, 0, 16.8894859851751, 0],
#   [0, 0, 16.896235810280498, 0],
#   [0, 0, 16.88410145442874, 0],
#   [0, 0, 16.851898342740654, 0],
#   [0, 0, 16.798767847784433, 0],
#   [0, 0, 16.795238110005315, 0],
#   [0, 0, 16.725363705322994, 0],
#   [0, 0, 16.626084396476124, 0],
#   [0, 0, 16.533087902978103, 0],
#   [0, 0, 16.417405446295632, 0],
#   [0, 0, 16.38158211358345, 0],
#   [0, 0, 16.333972711703524, 0],
#   [0, 0, 16.2988579803799, 0],
#   [0, 0, 16.26601011187279, 0],
#   [0, 0, 16.331916527239812, 0],
#   [0, 0, 16.404520143908453, 0],
#   [0, 0, 16.616268076247334, 0],
#   [0, 0, 16.718284080645766, 0],
#   [0, 0, 16.772394218432286, 0],
#   [0, 0, 16.80023100947071, 0],
#   [0, 0, 16.813432831487397, 0],
#   [0, 0, 16.807658624884024, 0],
#   [0, 0, 16.782213119963117, 0],
#   [0, 0, 16.73610593058273, 0],
#   [0, 0, 16.66867354321413, 0],
#   [0, 0, 16.579296617010456, 0],
#   [0, 0, 16.467364843687818, 0],
#   [0, 0, 16.468029480272182, 0],
#   [0, 0, 16.44654452314984, 0],
#   [0, 0, 16.454573075850494, 0],
#   [0, 0, 16.427826909713634, 0],
#   [0, 0, 16.3915569326794, 0],
#   [0, 0, 16.360240021284262, 0],
#   [0, 0, 16.423026918213484, 0],
#   [0, 0, 16.49183084726063, 0],
#   [0, 0, 16.54950040367932, 0],
#   [0, 0, 16.602313957443453, 0],
#   [0, 0, 16.773509827371115, 0],
#   [0, 0, 16.8359682850618, 0],
#   [0, 0, 16.85311075299621, 0],
#   [0, 0, 16.838960778987314, 0],
#   [0, 0, 16.807253672733378, 0],
#   [0, 0, 16.754166123590505, 0],
#   [0, 0, 16.679604039483586, 0],
#   [0, 0, 16.58281659275022, 0],
#   [0, 0, 16.463188655158728, 0],
#   [0, 0, 16.359866821822944, 0],
#   [0, 0, 16.257347866924455, 0],
#   [0, 0, 16.400186627521418, 0],
#   [0, 0, 16.43772715058588, 0],
#   [0, 0, 16.46209209678313, 0],
#   [0, 0, 16.550705916118336, 0],
#   [0, 0, 16.613501658768644, 0],
#   [0, 0, 16.67345825085225, 0],
#   [0, 0, 16.72949704648292, 0],
#   [0, 0, 16.772866629107853, 0],
#   [0, 0, 16.802447788026186, 0],
#   [0, 0, 16.815096536601757, 0],
#   [0, 0, 16.809368013997062, 0],
#   [0, 0, 16.8378620528953, 0],
#   [0, 0, 16.797797877267904, 0],
#   [0, 0, 16.729075793871342, 0],
#   [0, 0, 16.639674955758036, 0],
#   [0, 0, 16.527362327674044, 0],
#   [0, 0, 16.417852566948294, 0],
#   [0, 0, 16.333381404771238, 0],
#   [0, 0, 16.298136527872742, 0],
#   [0, 0, 16.255216875394755, 0],
#   [0, 0, 16.223639242509552, 0],
#   [0, 0, 16.384552582479444, 0],
#   [0, 0, 16.55414126324038, 0],
#   [0, 0, 16.680800039021833, 0],
#   [0, 0, 16.750995301077097, 0],
#   [0, 0, 16.8005629655707, 0],
#   [0, 0, 16.839744972937655, 0],
#   [0, 0, 16.863814493646007, 0],
#   [0, 0, 16.87055068241368, 0],
#   [0, 0, 16.858434099423107, 0],
#   [0, 0, 16.826282447015707, 0],
#   [0, 0, 16.773246537657236, 0],
#   [0, 0, 16.780766248620225, 0],
#   [0, 0, 16.717116433646424, 0],
#   [0, 0, 16.62376236310239, 0],
#   [0, 0, 16.534786044649426, 0],
#   [0, 0, 16.416896507436, 0],
#   [0, 0, 16.381245233383805, 0],
#   [0, 0, 16.333433017330517, 0],
#   [0, 0, 16.298218259128685, 0],
#   [0, 0, 16.35911740010405, 0],
#   [0, 0, 16.429472200122785, 0],
#   [0, 0, 16.489272287262388, 0],
#   [0, 0, 16.67976267114765, 0],
#   [0, 0, 16.759058866120604, 0],
#   [0, 0, 16.793686286088043, 0],
#   [0, 0, 16.805267670514276, 0],
#   [0, 0, 16.799746602786996, 0],
#   [0, 0, 16.774318958227173, 0],
#   [0, 0, 16.72836217618588, 0],
#   [0, 0, 16.661102646321485, 0],
#   [0, 0, 16.571922179945904, 0],
#   [0, 0, 16.460193612788768, 0],
#   [0, 0, 16.349010557375482, 0],
#   [0, 0, 16.407469061009444, 0],
#   [0, 0, 16.443585621824024, 0],
#   [0, 0, 16.44687746481603, 0],
#   [0, 0, 16.43254758479812, 0],
#   [0, 0, 16.39636472014462, 0],
#   [0, 0, 16.45932092917918, 0],
#   [0, 0, 16.52772486913157, 0],
#   [0, 0, 16.585315056774785, 0],
#   [0, 0, 16.638083050083928, 0],
#   [0, 0, 16.676940375400495, 0],
#   [0, 0, 16.810381667059257, 0],
#   [0, 0, 16.844546679224187, 0],
#   [0, 0, 16.83555082756169, 0],
#   [0, 0, 16.80282803242803, 0],
#   [0, 0, 16.749943873974335, 0],
#   [0, 0, 16.675335906696485, 0],
#   [0, 0, 16.578559487558326, 0],
#   [0, 0, 16.458937101766512, 0],
#   [0, 0, 16.355644542695618, 0],
#   [0, 0, 16.25309071898955, 0],
#   [0, 0, 16.21666135938557, 0],
#   [0, 0, 16.35922063389722, 0],
#   [0, 0, 16.415561203689503, 0],
#   [0, 0, 16.541080969381802, 0],
#   [0, 0, 16.62947408932191, 0],
#   [0, 0, 16.68405331852514, 0],
#   [0, 0, 16.740724983812115, 0],
#   [0, 0, 16.783785529879335, 0],
#   [0, 0, 16.813325271821512, 0],
#   [0, 0, 16.82594779027085, 0],
#   [0, 0, 16.82020894513126, 0],
#   [0, 0, 16.794792146543355, 0],
#   [0, 0, 16.81275797058366, 0],
#   [0, 0, 16.761727125703395, 0],
#   [0, 0, 16.675333978115443, 0],
#   [0, 0, 16.562005194308302, 0],
#   [0, 0, 16.454368153258486, 0],
#   [0, 0, 16.367162818974336, 0],
#   [0, 0, 16.332047225067015, 0],
#   [0, 0, 16.288862874804458, 0],
#   [0, 0, 16.25710709857952, 0],
#   [0, 0, 16.316169353369, 0],
#   [0, 0, 16.577149800278427, 0],
#   [0, 0, 16.706024600664218, 0],
#   [0, 0, 16.794957473422475, 0],
#   [0, 0, 16.828361296797027, 0],
#   [0, 0, 16.852999045714313, 0],
#   [0, 0, 16.85939146642062, 0],
#   [0, 0, 16.847326044196045, 0],
#   [0, 0, 16.81529048692825, 0],
#   [0, 0, 16.76242860283453, 0],
#   [0, 0, 16.688028428478155, 0],
#   [0, 0, 16.591434438974403, 0],
#   [0, 0, 16.590811439861575, 0],
#   [0, 0, 16.561374457326835, 0],
#   [0, 0, 16.49524306349336, 0],
#   [0, 0, 16.483416010999058, 0],
#   [0, 0, 16.436901213639292, 0],
#   [0, 0, 16.49389377171504, 0],
#   [0, 0, 16.55963887815165, 0],
#   [0, 0, 16.617445683837072, 0],
#   [0, 0, 16.67249928151963, 0],
#   [0, 0, 16.715159491579698, 0],
#   [0, 0, 16.744286095925368, 0],
#   [0, 0, 16.83682053056255, 0],
#   [0, 0, 16.84431581922837, 0],
#   [0, 0, 16.816331620698804, 0],
#   [0, 0, 16.77088939358715, 0],
#   [0, 0, 16.703513964990552, 0],
#   [0, 0, 16.61427251204022, 0],
#   [0, 0, 16.502393219412518, 0],
#   [0, 0, 16.392019391675596, 0],
#   [0, 0, 16.30927445309359, 0],
#   [0, 0, 16.274067268431708, 0],
#   [0, 0, 16.420401481184413, 0],
#   [0, 0, 16.485020259506264, 0],
#   [0, 0, 16.611814334852273, 0],
#   [0, 0, 16.699659649349616, 0],
#   [0, 0, 16.75035211668863, 0],
#   [0, 0, 16.802641618027238, 0],
#   [0, 0, 16.84063677690235, 0],
#   [0, 0, 16.864559983722838, 0],
#   [0, 0, 16.871152812320844, 0],
#   [0, 0, 16.8590353464062, 0],
#   [0, 0, 16.826963599363488, 0],
#   [0, 0, 16.84779244146996, 0],
#   [0, 0, 16.796815637409843, 0],
#   [0, 0, 16.710340418790345, 0],
#   [0, 0, 16.58990018351815, 0],
#   [0, 0, 16.489288320308386, 0],
#   [0, 0, 16.379455761472588, 0],
#   [0, 0, 16.343400200742163, 0],
#   [0, 0, 16.29645795896326, 0],
#   [0, 0, 16.261735191669175, 0],
#   [0, 0, 16.322873327360902, 0],
#   [0, 0, 16.393306466383088, 0],
#   [0, 0, 16.603740420811373, 0],
#   [0, 0, 16.705696542550957, 0],
#   [0, 0, 16.76025299667965, 0],
#   [0, 0, 16.787434683041134, 0],
#   [0, 0, 16.800488291287163, 0],
#   [0, 0, 16.794672914587814, 0],
#   [0, 0, 16.769314582182204, 0],
#   [0, 0, 16.72336208421663, 0],
#   [0, 0, 16.656134045233234, 0],
#   [0, 0, 16.566992899019954, 0],
#   [0, 0, 16.45531007129758, 0],
#   [0, 0, 16.4569622705053, 0],
#   [0, 0, 16.4371010473112, 0],
#   [0, 0, 16.44574908856437, 0],
#   [0, 0, 16.41957221631088, 0],
#   [0, 0, 16.38370180647616, 0],
#   [0, 0, 16.352383367880446, 0],
#   [0, 0, 16.4151883430863, 0],
#   [0, 0, 16.483980712475244, 0],
#   [0, 0, 16.541647254115414, 0],
#   [0, 0, 16.59444234955199, 0],
#   [0, 0, 16.76747677030856, 0],
#   [0, 0, 16.83128117887586, 0],
#   [0, 0, 16.849760557214882, 0],
#   [0, 0, 16.83534994346865, 0],
#   [0, 0, 16.80370031575635, 0],
#   [0, 0, 16.750613017403847, 0],
#   [0, 0, 16.676065029308536, 0],
#   [0, 0, 16.579297123335007, 0],
#   [0, 0, 16.459691158820004, 0],
#   [0, 0, 16.356335052328053, 0],
#   [0, 0, 16.25389123372745, 0],
#   [0, 0, 16.390422116168914, 0],
#   [0, 0, 16.51934309628767, 0],
#   [0, 0, 16.628517945646482, 0],
#   [0, 0, 16.685478175626606, 0],
#   [0, 0, 16.73764059536501, 0],
#   [0, 0, 16.778890548776598, 0],
#   [0, 0, 16.80728031344438, 0],
#   [0, 0, 16.819392303976223, 0],
#   [0, 0, 16.813560417308928, 0],
#   [0, 0, 16.788321936003577, 0],
#   [0, 0, 16.74266869281036, 0],
#   [0, 0, 16.73272331780835, 0],
#   [0, 0, 16.66060116227688, 0],
#   [0, 0, 16.555173615506085, 0],
#   [0, 0, 16.44655445080421, 0],
#   [0, 0, 16.359878671591805, 0],
#   [0, 0, 16.324955879630085, 0],
#   [0, 0, 16.281998251469116, 0],
#   [0, 0, 16.250409531261216, 0],
#   [0, 0, 16.220780493197825, 0],
#   [0, 0, 16.28458583501421, 0],
#   [0, 0, 16.535146724602154, 0],
#   [0, 0, 16.65883598570118, 0],
#   [0, 0, 16.742642410135918, 0],
#   [0, 0, 16.77497529469664, 0],
#   [0, 0, 16.800265853736626, 0],
#   [0, 0, 16.806724735325997, 0],
#   [0, 0, 16.79470340551668, 0],
#   [0, 0, 16.762656799112683, 0],
#   [0, 0, 16.709808216615585, 0],
#   [0, 0, 16.635454299178605, 0],
#   [0, 0, 16.538980732237125, 0],
#   [0, 0, 16.53128570555694, 0],
#   [0, 0, 16.493215004791576, 0],
#   [0, 0, 16.417342895339896, 0],
#   [0, 0, 16.495347602208945, 0],
#   [0, 0, 16.543696959086446, 0],
#   [0, 0, 16.59703413409551, 0],
#   [0, 0, 16.647184472804998, 0],
#   [0, 0, 16.687346673814975, 0],
#   [0, 0, 16.714910844876407, 0],
#   [0, 0, 16.726685570902724, 0],
#   [0, 0, 16.807258433104774, 0],
#   [0, 0, 16.80344945811495, 0],
#   [0, 0, 16.760251267817633, 0],
#   [0, 0, 16.69306197740373, 0],
#   [0, 0, 16.60447095385076, 0],
#   [0, 0, 16.49314786414141, 0],
#   [0, 0, 16.382800077548684, 0],
#   [0, 0, 16.30111300690197, 0],
#   [0, 0, 16.26620450004637, 0],
#   [0, 0, 16.22388602716476, 0],
#   [0, 0, 16.192749853957604, 0],
#   [0, 0, 16.34565331997889, 0],
#   [0, 0, 16.49410172956694, 0],
#   [0, 0, 16.607488941009777, 0],
#   [0, 0, 16.66617245834733, 0],
#   [0, 0, 16.718070252468053, 0],
#   [0, 0, 16.756802451608305, 0],
#   [0, 0, 16.78092259183455, 0],
#   [0, 0, 16.78763256189399, 0],
#   [0, 0, 16.77557320538206, 0],
#   [0, 0, 16.743558755421546, 0],
#   [0, 0, 16.791750154110222, 0],
#   [0, 0, 16.756921440673054, 0],
#   [0, 0, 16.68506979814854, 0],
#   [0, 0, 16.577799987859017, 0],
#   [0, 0, 16.47584782547165, 0],
#   [0, 0, 16.362125964686445, 0],
#   [0, 0, 16.326179233012144, 0],
#   [0, 0, 16.27877281788215, 0],
#   [0, 0, 16.33734705684528, 0],
#   [0, 0, 16.403289950921113, 0],
#   [0, 0, 16.46111062527513, 0],
#   [0, 0, 16.657238628502906, 0],
#   [0, 0, 16.73970209201623, 0],
#   [0, 0, 16.777438715196297, 0],
#   [0, 0, 16.788038635177454, 0],
#   [0, 0, 16.78261879080481, 0],
#   [0, 0, 16.75727030451449, 0],
#   [0, 0, 16.711522885747918, 0],
#   [0, 0, 16.644528512524737, 0],
#   [0, 0, 16.555649540696386, 0],
#   [0, 0, 16.444245492121706, 0],
#   [0, 0, 16.332693046856406, 0],
#   [0, 0, 16.395839630205455, 0],
#   [0, 0, 16.43614186112368, 0],
#   [0, 0, 16.444805161880275, 0],
#   [0, 0, 16.436781393880167, 0],
#   [0, 0, 16.406039201382804, 0],
#   [0, 0, 16.378063243856896, 0],
#   [0, 0, 16.443165938382784, 0],
#   [0, 0, 16.514027405579217, 0],
#   [0, 0, 16.572955261268202, 0],
#   [0, 0, 16.626680529384966, 0],
#   [0, 0, 16.666070046870814, 0],
#   [0, 0, 16.77689457382361, 0],
#   [0, 0, 16.798118659425086, 0],
#   [0, 0, 16.783215600283, 0],
#   [0, 0, 16.75166631677547, 0],
#   [0, 0, 16.698581465349587, 0],
#   [0, 0, 16.62411276410304, 0],
#   [0, 0, 16.527492523623028, 0],
#   [0, 0, 16.408122278778944, 0],
#   [0, 0, 16.303807689348968, 0],
#   [0, 0, 16.20281830765572, 0],
#   [0, 0, 16.35382513166733, 0],
#   [0, 0, 16.406564031211506, 0],
#   [0, 0, 16.536346327003162, 0],
#   [0, 0, 16.626904044043044, 0],
#   [0, 0, 16.678231540242546, 0],
#   [0, 0, 16.733424123986563, 0],
#   [0, 0, 16.77550513121325, 0],
#   [0, 0, 16.8044924803954, 0],
#   [0, 0, 16.816864607640525, 0],
#   [0, 0, 16.811082600402734, 0],
#   [0, 0, 16.785755848453817, 0],
#   [0, 0, 16.815299666076434, 0],
#   [0, 0, 16.771191727043046, 0],
#   [0, 0, 16.691003930398082, 0],
#   [0, 0, 16.576539333717754, 0],
#   [0, 0, 16.46988204878452, 0],
#   [0, 0, 16.381816520955283, 0],
#   [0, 0, 16.34687040963888, 0],
#   [0, 0, 16.30368008401712, 0],
#   [0, 0, 16.271941708532808, 0],
#   [0, 0, 16.33109888154778, 0],
#   [0, 0, 16.39826992699551, 0],
#   [0, 0, 16.600211549211224, 0],
#   [0, 0, 16.696682359033655, 0],
#   [0, 0, 16.746797288676845, 0],
#   [0, 0, 16.76814521915562, 0],
#   [0, 0, 16.775183987966678, 0],
#   [0, 0, 16.763047036097948, 0],
#   [0, 0, 16.73116792816092, 0],
#   [0, 0, 16.67853348863663, 0],
#   [0, 0, 16.604474336492522, 0],
#   [0, 0, 16.50834034336997, 0],
#   [0, 0, 16.529188077450986, 0],
#   [0, 0, 16.513280161833364, 0],
#   [0, 0, 16.460573183200076, 0],
#   [0, 0, 16.457800135805893, 0],
#   [0, 0, 16.42053039971786, 0],
#   [0, 0, 16.475043201657304, 0],
#   [0, 0, 16.54064009203662, 0],
#   [0, 0, 16.598076101425505, 0],
#   [0, 0, 16.652918343672575, 0],
#   [0, 0, 16.69543320498569, 0],
#   [0, 0, 16.7244803501104, 0],
#   [0, 0, 16.830346208990157, 0],
#   [0, 0, 16.84572495102899, 0],
#   [0, 0, 16.81956022216826, 0],
#   [0, 0, 16.77376856605099, 0],
#   [0, 0, 16.706461204041577, 0],
#   [0, 0, 16.61719283370468, 0],
#   [0, 0, 16.505291257000078, 0],
#   [0, 0, 16.39517831252613, 0],
#   [0, 0, 16.312087768590107, 0],
#   [0, 0, 16.27691151157928, 0],
#   [0, 0, 16.23422573240853, 0],
#   [0, 0, 16.377419052983836, 0],
#   [0, 0, 16.517834683300205, 0],
#   [0, 0, 16.626478282183836, 0],
#   [0, 0, 16.68154584512563, 0],
#   [0, 0, 16.73285122576655, 0],
#   [0, 0, 16.77088123084021, 0],
#   [0, 0, 16.79469436572369, 0],
#   [0, 0, 16.8012707436404, 0],
#   [0, 0, 16.78920383061346, 0],
#   [0, 0, 16.75725841293658, 0],
#   [0, 0, 16.8006726991091, 0],
#   [0, 0, 16.763419082692614, 0],
#   [0, 0, 16.689710941381165, 0],
#   [0, 0, 16.58076491640677, 0],
#   [0, 0, 16.479099027798036, 0],
#   [0, 0, 16.36642927800187, 0],
#   [0, 0, 16.330512364193602, 0],
#   [0, 0, 16.283276602808204, 0],
#   [0, 0, 16.341994675983923, 0],
#   [0, 0, 16.40804373716387, 0],
#   [0, 0, 16.46594202650035, 0],
#   [0, 0, 16.672620578464862, 0],
#   [0, 0, 16.76243767895427, 0],
#   [0, 0, 16.807425759459097, 0],
#   [0, 0, 16.816608900722695, 0],
#   [0, 0, 16.811459910003023, 0],
#   [0, 0, 16.786016798910158, 0],
#   [0, 0, 16.740207353355768, 0],
#   [0, 0, 16.673095298966974, 0],
#   [0, 0, 16.584059419995587, 0],
#   [0, 0, 16.47245485791494, 0],
#   [0, 0, 16.361432011697097, 0],
#   [0, 0, 16.429898847614616, 0],
#   [0, 0, 16.470487401208157, 0],
#   [0, 0, 16.476456582657576, 0],
#   [0, 0, 16.463968390781623, 0],
#   [0, 0, 16.5198326437496, 0],
#   [0, 0, 16.586344365385653, 0],
#   [0, 0, 16.641978575482096, 0],
#   [0, 0, 16.69376674365999, 0],
#   [0, 0, 16.731994260159105, 0],
#   [0, 0, 16.75588581091472, 0],
#   [0, 0, 16.762487560638796, 0],
#   [0, 0, 16.813977139153167, 0],
#   [0, 0, 16.79082939839982, 0],
#   [0, 0, 16.736268835907424, 0],
#   [0, 0, 16.66221066850827, 0],
#   [0, 0, 16.56558725523688, 0],
#   [0, 0, 16.446211982460188, 0],
#   [0, 0, 16.34260798737968, 0],
#   [0, 0, 16.240836154008193, 0],
#   [0, 0, 16.204459026251154, 0],
#   [0, 0, 16.158392676844606, 0],
#   [0, 0, 16.313879525224614, 0],
#   [0, 0, 16.481877693774717, 0],
#   [0, 0, 16.60969625598342, 0],
#   [0, 0, 16.681032831660243, 0],
#   [0, 0, 16.734099686247323, 0],
#   [0, 0, 16.77758855290282, 0],
#   [0, 0, 16.806922885904402, 0],
#   [0, 0, 16.819528493873566, 0],
#   [0, 0, 16.81378438887751, 0],
#   [0, 0, 16.788386227639993, 0],
#   [0, 0, 16.742411551439666, 0],
#   [0, 0, 16.745743112455774, 0],
#   [0, 0, 16.68212918481192, 0],
#   [0, 0, 16.585179110771175, 0],
#   [0, 0, 16.48494837123842, 0],
#   [0, 0, 16.392784031735008, 0],
#   [0, 0, 16.35795352730398, 0],
#   [0, 0, 16.314296569660865, 0],
#   [0, 0, 16.282267519119216, 0],
#   [0, 0, 16.252254853124178, 0],
#   [0, 0, 16.31591346446888, 0],
#   [0, 0, 16.384994233714835, 0],
#   [0, 0, 16.596060443927072, 0],
#   [0, 0, 16.697547837231305, 0],
#   [0, 0, 16.752018070947265, 0],
#   [0, 0, 16.77294340148186, 0],
#   [0, 0, 16.78025344262192, 0],
#   [0, 0, 16.7680827216195, 0],
#   [0, 0, 16.73611687692784, 0],
#   [0, 0, 16.68333099269436, 0],
#   [0, 0, 16.609090178084834, 0],
#   [0, 0, 16.512755781864445, 0],
#   [0, 0, 16.53647095349686, 0],
#   [0, 0, 16.522857839279656, 0],
#   [0, 0, 16.471625458623045, 0],
#   [0, 0, 16.46850088401233, 0],
#   [0, 0, 16.432234201859533, 0],
#   [0, 0, 16.48638896825621, 0],
#   [0, 0, 16.551961151638917, 0],
#   [0, 0, 16.609353565300545, 0],
#   [0, 0, 16.664189251205674, 0],
#   [0, 0, 16.706704697430208, 0],
#   [0, 0, 16.735755699472758, 0],
#   [0, 0, 16.842816701039947, 0],
#   [0, 0, 16.859096381348508, 0],
#   [0, 0, 16.833703643837527, 0],
#   [0, 0, 16.787726022097573, 0],
#   [0, 0, 16.720392977210462, 0],
#   [0, 0, 16.631047482041744, 0],
#   [0, 0, 16.519051897005223, 0],
#   [0, 0, 16.409184264660936, 0],
#   [0, 0, 16.325653840407007, 0],
#   [0, 0, 16.29049396945449, 0],
#   [0, 0, 16.24775812562684, 0],
#   [0, 0, 16.450520815191133, 0],
#   [0, 0, 16.56105133274847, 0],
#   [0, 0, 16.62752200516901, 0],
#   [0, 0, 16.674913496469564, 0],
#   [0, 0, 16.71267496550045, 0],
#   [0, 0, 16.735922079290866, 0],
#   [0, 0, 16.742346729969903, 0],
#   [0, 0, 16.73031409488811, 0],
#   [0, 0, 16.698576933075845, 0],
#   [0, 0, 16.646219433302498, 0],
#   [0, 0, 16.58964851233379, 0],
#   [0, 0, 16.490494089546164, 0],
#   [0, 0, 16.37257423909259, 0],
#   [0, 0, 16.26716542818715, 0],
#   [0, 0, 16.168772318823866, 0],
#   [0, 0, 16.13240809994751, 0],
#   [0, 0, 16.086804945938596, 0],
#   [0, 0, 16.052974910759705, 0],
#   [0, 0, 16.02128274818155, 0],
#   [0, 0, 15.994387428324119, 0],
#   [0, 0, 15.970073280056036, 0],
#   [0, 0, 15.948420412123246, 0],
#   [0, 0, 16.04832083749163, 0],
#   [0, 0, 16.075338981295385, 0],
#   [0, 0, 16.077823790347157, 0],
#   [0, 0, 16.134256776887767, 0],
#   [0, 0, 16.213877728875772, 0],
#   [0, 0, 16.281790300967014, 0],
#   [0, 0, 16.34335404149474, 0],
#   [0, 0, 16.391486223547183, 0],
#   [0, 0, 16.42477968842127, 0],
#   [0, 0, 16.440864330814236, 0],
#   [0, 0, 16.438470862905863, 0],
#   [0, 0, 16.41655174321078, 0],
#   [0, 0, 16.37437536790072, 0],
#   [0, 0, 16.31135331544729, 0],
#   [0, 0, 16.226961188607063, 0],
#   [0, 0, 16.120652739184393, 0],
#   [0, 0, 16.00072727517651, 0],
#   [0, 0, 15.937537259930663, 0],
#   [0, 0, 15.901951326104786, 0],
#   [0, 0, 15.945945284516375, 0],
#   [0, 0, 16.11728132714307, 0],
#   [0, 0, 16.192253900240527, 0],
#   [0, 0, 16.235018640855806, 0],
#   [0, 0, 16.268201556289558, 0],
#   [0, 0, 16.287634890930384, 0],
#   [0, 0, 16.290789181765813, 0],
#   [0, 0, 16.276073805208853, 0],
#   [0, 0, 16.242229108099952, 0],
#   [0, 0, 16.18832093818199, 0],
#   [0, 0, 16.186301039137103, 0],
#   [0, 0, 16.121821908053246, 0],
#   [0, 0, 16.02738417274286, 0],
#   [0, 0, 15.941911622356221, 0],
#   [0, 0, 15.854415637724108, 0],
#   [0, 0, 15.81894421146037, 0],
#   [0, 0, 15.77263299719518, 0],
#   [0, 0, 15.739222478532655, 0],
#   [0, 0, 15.707369600473484, 0],
#   [0, 0, 15.680585528114106, 0],
#   [0, 0, 15.847795870899063, 0],
#   [0, 0, 15.978739810118336, 0],
#   [0, 0, 16.054952006434185, 0],
#   [0, 0, 16.188541248803205, 0],
#   [0, 0, 16.281369123768307, 0],
#   [0, 0, 16.34149030925755, 0],
#   [0, 0, 16.401595877695215, 0],
#   [0, 0, 16.447295764981945, 0],
#   [0, 0, 16.478908035184233, 0],
#   [0, 0, 16.493354999873596, 0],
#   [0, 0, 16.620492814657652, 0],
#   [0, 0, 16.64367848617859, 0],
#   [0, 0, 16.625285136706932, 0],
#   [0, 0, 16.561343104630314, 0],
#   [0, 0, 16.473629094762558, 0],
#   [0, 0, 16.363833834892052, 0],
#   [0, 0, 16.2521657978118, 0],
#   [0, 0, 16.17375046643572, 0],
#   [0, 0, 16.13855039727141, 0],
#   [0, 0, 16.096543102810973, 0],
#   [0, 0, 16.255392313971935, 0],
#   [0, 0, 16.450642607985557, 0],
#   [0, 0, 16.591503471377393, 0],
#   [0, 0, 16.673980113345472, 0],
#   [0, 0, 16.717637708636676, 0],
#   [0, 0, 16.75501862760149, 0],
#   [0, 0, 16.776943732352375, 0],
#   [0, 0, 16.781941686354024, 0],
#   [0, 0, 16.76826042511779, 0],
#   [0, 0, 16.734718552414666, 0],
#   [0, 0, 16.68040896606335, 0],
#   [0, 0, 16.604620467682025, 0],
#   [0, 0, 16.57830175179154, 0],
#   [0, 0, 16.49418974012557, 0],
#   [0, 0, 16.423149034161916, 0],
#   [0, 0, 16.320400364044072, 0],
#   [0, 0, 16.28767164376883, 0],
#   [0, 0, 16.238397391508652, 0],
#   [0, 0, 16.202604912748846, 0],
#   [0, 0, 16.169026600263326, 0],
#   [0, 0, 16.140523516689726, 0],
#   [0, 0, 16.209158496464713, 0],
#   [0, 0, 16.479476530243716, 0],
#   [0, 0, 16.624750781346584, 0],
#   [0, 0, 16.723714803804636, 0],
#   [0, 0, 16.765206313521844, 0],
#   [0, 0, 16.797447618685723, 0],
#   [0, 0, 16.81172560156708, 0],
#   [0, 0, 16.807711077092947, 0],
#   [0, 0, 16.783902992720737, 0],
#   [0, 0, 16.739476098491586, 0],
#   [0, 0, 16.67375140927687, 0],
#   [0, 0, 16.586120140833938, 0],
#   [0, 0, 16.5846729278162, 0],
#   [0, 0, 16.538358388804983, 0],
#   [0, 0, 16.49306655466882, 0],
#   [0, 0, 16.482027069075166, 0],
#   [0, 0, 16.438459198379313, 0],
#   [0, 0, 16.405211766996015, 0],
#   [0, 0, 16.374497255066277, 0],
#   [0, 0, 16.437031135308164, 0],
#   [0, 0, 16.505103600181275, 0],
#   [0, 0, 16.56186966275939, 0],
#   [0, 0, 16.613501117881924, 0],
#   [0, 0, 16.751334395466372, 0],
#   [0, 0, 16.793684856193984, 0],
#   [0, 0, 16.794948229526213, 0],
#   [0, 0, 16.78202157921023, 0],
#   [0, 0, 16.748145196545995, 0],
#   [0, 0, 16.693577690640446, 0],
#   [0, 0, 16.61744716149968, 0],
#   [0, 0, 16.51914859269859, 0],
#   [0, 0, 16.398044447641634, 0],
#   [0, 0, 16.295268609781743, 0],
#   [0, 0, 16.37194087362474, 0]],
#  'traj': [array([[-5.96253687e-01,  2.90374623e+00,  6.40374614e+00,
#            9.90374606e+00,  1.34037460e+01,  1.69037459e+01,
#            2.04037458e+01,  2.39037457e+01,  2.74037456e+01,
#            3.09037455e+01,  3.44037455e+01,  3.79037454e+01,
#            4.14037453e+01,  4.49037452e+01,  4.84037451e+01,
#            5.19037450e+01,  5.54037450e+01,  5.89037449e+01,
#            6.22366770e+01,  6.50848034e+01,  6.71766040e+01,
#            6.87549334e+01,  7.01697382e+01,  7.15328542e+01,
#            7.28787608e+01],
#          [-2.96682634e-01, -2.95911373e-01, -2.95140112e-01,
#           -2.94368851e-01, -2.93597591e-01, -2.92826330e-01,
#           -2.92055069e-01, -2.91283808e-01, -2.90512548e-01,
#           -2.89741287e-01, -2.88970026e-01, -2.88198765e-01,
#           -2.87427505e-01, -2.86656244e-01, -2.85884983e-01,
#           -2.85113722e-01, -2.84342461e-01, -2.83571201e-01,
#            7.84868498e-01,  2.81911922e+00,  5.62525003e+00,
#            8.74917005e+00,  1.19504710e+01,  1.51741202e+01,
#            1.84049925e+01],
#          [ 1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            0.00000000e+00],
#          [ 2.20360217e-04,  2.20360217e-04,  2.20360217e-04,
#            2.20360217e-04,  2.20360217e-04,  2.20360217e-04,
#            2.20360217e-04,  2.20360217e-04,  2.20360217e-04,
#            2.20360217e-04,  2.20360217e-04,  2.20360217e-04,
#            2.20360217e-04,  2.20360217e-04,  2.20360217e-04,
#            2.20360217e-04,  2.20360217e-04,  1.55220360e-01,
#            4.65220360e-01,  7.75220360e-01,  1.01659293e+00,
#            1.12881253e+00,  1.16270440e+00,  1.17341548e+00,
#            1.17608173e+00]]),
#   array([[-5.99862201e-01,  2.90013775e+00,  6.40013771e+00,
#            9.90013766e+00,  1.34001376e+01,  1.69001376e+01,
#            2.04001375e+01,  2.39001375e+01,  2.74001374e+01,
#            3.09001374e+01,  3.44001373e+01,  3.79001373e+01,
#            4.14001372e+01,  4.49001372e+01,  4.84001371e+01,
#            5.19001371e+01,  5.54001371e+01,  5.89001370e+01,
#            6.22331303e+01,  6.50813731e+01,  6.71733344e+01,
#            6.87518426e+01,  7.01668306e+01,  7.15301312e+01,
#            7.28762227e+01],
#          [-2.96662359e-01, -2.96091449e-01, -2.95520538e-01,
#           -2.94949627e-01, -2.94378716e-01, -2.93807805e-01,
#           -2.93236894e-01, -2.92665983e-01, -2.92095072e-01,
#           -2.91524161e-01, -2.90953250e-01, -2.90382339e-01,
#           -2.89811428e-01, -2.89240517e-01, -2.88669607e-01,
#           -2.88098696e-01, -2.87527785e-01, -2.86956874e-01,
#            7.81292037e-01,  2.81537972e+00,  5.62139079e+00,
#            8.74522045e+00,  1.19464404e+01,  1.51700116e+01,
#            1.84008068e+01],
#          [ 1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            0.00000000e+00],
#          [ 1.63117407e-04,  1.63117407e-04,  1.63117407e-04,
#            1.63117407e-04,  1.63117407e-04,  1.63117407e-04,
#            1.63117407e-04,  1.63117407e-04,  1.63117407e-04,
#            1.63117407e-04,  1.63117407e-04,  1.63117407e-04,
#            1.63117407e-04,  1.63117407e-04,  1.63117407e-04,
#            1.63117407e-04,  1.63117407e-04,  1.55163117e-01,
#            4.65163117e-01,  7.75163117e-01,  1.01653568e+00,
#            1.12875529e+00,  1.16264716e+00,  1.17335824e+00,
#            1.17602449e+00]]),
#   array([[-6.06227129e-01,  2.89377281e+00,  6.39377274e+00,
#            9.89377267e+00,  1.33937726e+01,  1.68937725e+01,
#            2.03937725e+01,  2.38937724e+01,  2.73937723e+01,
#            3.08937723e+01,  3.43937722e+01,  3.78937722e+01,
#            4.13937721e+01,  4.48937720e+01,  4.83937720e+01,
#            5.18937719e+01,  5.53937718e+01,  5.88937718e+01,
#            6.22267328e+01,  6.50749143e+01,  6.71667908e+01,
#            6.87452048e+01,  7.01600961e+01,  7.15232994e+01,
#            7.28692935e+01],
#          [-2.96671783e-01, -2.95995234e-01, -2.95318685e-01,
#           -2.94642136e-01, -2.93965587e-01, -2.93289038e-01,
#           -2.92612489e-01, -2.91935940e-01, -2.91259391e-01,
#           -2.90582842e-01, -2.89906293e-01, -2.89229744e-01,
#           -2.88553195e-01, -2.87876646e-01, -2.87200097e-01,
#           -2.86523548e-01, -2.85846999e-01, -2.85170450e-01,
#            7.83179058e-01,  2.81735271e+00,  5.62342692e+00,
#            8.74730422e+00,  1.19485668e+01,  1.51721792e+01,
#            1.84030150e+01],
#          [ 1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            0.00000000e+00],
#          [ 1.93299709e-04,  1.93299709e-04,  1.93299709e-04,
#            1.93299709e-04,  1.93299709e-04,  1.93299709e-04,
#            1.93299709e-04,  1.93299709e-04,  1.93299709e-04,
#            1.93299709e-04,  1.93299709e-04,  1.93299709e-04,
#            1.93299709e-04,  1.93299709e-04,  1.93299709e-04,
#            1.93299709e-04,  1.93299709e-04,  1.55193300e-01,
#            4.65193300e-01,  7.75193300e-01,  1.01656587e+00,
#            1.12878547e+00,  1.16267734e+00,  1.17338842e+00,
#            1.17605467e+00]]),
#   array([[-6.15433572e-01,  2.88456633e+00,  6.38456624e+00,
#            9.88456615e+00,  1.33845661e+01,  1.68845660e+01,
#            2.03845659e+01,  2.38845658e+01,  2.73845657e+01,
#            3.08845656e+01,  3.43845655e+01,  3.78845654e+01,
#            4.13845653e+01,  4.48845652e+01,  4.83845651e+01,
#            5.18845650e+01,  5.53845649e+01,  5.88845648e+01,
#            6.22174849e+01,  6.50655885e+01,  6.71573575e+01,
#            6.87356518e+01,  7.01504205e+01,  7.15135003e+01,
#            7.28593706e+01],
#          [-2.96624304e-01, -2.95813667e-01, -2.95003030e-01,
#           -2.94192393e-01, -2.93381756e-01, -2.92571119e-01,
#           -2.91760482e-01, -2.90949845e-01, -2.90139208e-01,
#           -2.89328571e-01, -2.88517933e-01, -2.87707296e-01,
#           -2.86896659e-01, -2.86086022e-01, -2.85275385e-01,
#           -2.84464748e-01, -2.83654111e-01, -2.82843474e-01,
#            7.85633722e-01,  2.81991649e+00,  5.62607083e+00,
#            8.75000861e+00,  1.19513254e+01,  1.51749900e+01,
#            1.84058774e+01],
#          [ 1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            0.00000000e+00],
#          [ 2.31610594e-04,  2.31610594e-04,  2.31610594e-04,
#            2.31610594e-04,  2.31610594e-04,  2.31610594e-04,
#            2.31610594e-04,  2.31610594e-04,  2.31610594e-04,
#            2.31610594e-04,  2.31610594e-04,  2.31610594e-04,
#            2.31610594e-04,  2.31610594e-04,  2.31610594e-04,
#            2.31610594e-04,  2.31610594e-04,  1.55231611e-01,
#            4.65231611e-01,  7.75231611e-01,  1.01660418e+00,
#            1.12882378e+00,  1.16271565e+00,  1.17342673e+00,
#            1.17609298e+00]]),
#   array([[-6.27404839e-01,  2.87259499e+00,  6.37259482e+00,
#            9.87259465e+00,  1.33725945e+01,  1.68725943e+01,
#            2.03725941e+01,  2.38725940e+01,  2.73725938e+01,
#            3.08725936e+01,  3.43725935e+01,  3.78725933e+01,
#            4.13725931e+01,  4.48725930e+01,  4.83725928e+01,
#            5.18725926e+01,  5.53725924e+01,  5.88725923e+01,
#            6.22054269e+01,  6.50533678e+01,  6.71449124e+01,
#            6.87229569e+01,  7.01374696e+01,  7.15002916e+01,
#            7.28459035e+01],
#          [-2.96519350e-01, -2.95428828e-01, -2.94338306e-01,
#           -2.93247784e-01, -2.92157263e-01, -2.91066741e-01,
#           -2.89976219e-01, -2.88885697e-01, -2.87795175e-01,
#           -2.86704653e-01, -2.85614132e-01, -2.84523610e-01,
#           -2.83433088e-01, -2.82342566e-01, -2.81252044e-01,
#           -2.80161522e-01, -2.79071000e-01, -2.77980479e-01,
#            7.90763238e-01,  2.82527375e+00,  5.63159536e+00,
#            8.75565934e+00,  1.19570893e+01,  1.51808629e+01,
#            1.84118579e+01],
#          [ 1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            0.00000000e+00],
#          [ 3.11577676e-04,  3.11577676e-04,  3.11577676e-04,
#            3.11577676e-04,  3.11577676e-04,  3.11577676e-04,
#            3.11577676e-04,  3.11577676e-04,  3.11577676e-04,
#            3.11577676e-04,  3.11577676e-04,  3.11577676e-04,
#            3.11577676e-04,  3.11577676e-04,  3.11577676e-04,
#            3.11577676e-04,  3.11577676e-04,  1.55311578e-01,
#            4.65311578e-01,  7.75311578e-01,  1.01668414e+00,
#            1.12890375e+00,  1.16279562e+00,  1.17350670e+00,
#            1.17617295e+00]]),
#   array([[-6.42113778e-01,  2.85788583e+00,  6.35788543e+00,
#            9.85788504e+00,  1.33578846e+01,  1.68578843e+01,
#            2.03578839e+01,  2.38578835e+01,  2.73578831e+01,
#            3.08578827e+01,  3.43578823e+01,  3.78578819e+01,
#            4.13578815e+01,  4.48578811e+01,  4.83578807e+01,
#            5.18578803e+01,  5.53578799e+01,  5.88578795e+01,
#            6.21905402e+01,  6.50381499e+01,  6.71292378e+01,
#            6.87067738e+01,  7.01207654e+01,  7.14830627e+01,
#            7.28281488e+01],
#          [-2.96307263e-01, -2.94647115e-01, -2.92986966e-01,
#           -2.91326818e-01, -2.89666669e-01, -2.88006521e-01,
#           -2.86346372e-01, -2.84686224e-01, -2.83026075e-01,
#           -2.81365927e-01, -2.79705778e-01, -2.78045630e-01,
#           -2.76385481e-01, -2.74725333e-01, -2.73065184e-01,
#           -2.71405036e-01, -2.69744887e-01, -2.68084739e-01,
#            8.01201384e-01,  2.83617538e+00,  5.64283735e+00,
#            8.76715811e+00,  1.19688182e+01,  1.51928136e+01,
#            1.84240275e+01],
#          [ 1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            0.00000000e+00],
#          [ 4.74328158e-04,  4.74328158e-04,  4.74328158e-04,
#            4.74328158e-04,  4.74328158e-04,  4.74328158e-04,
#            4.74328158e-04,  4.74328158e-04,  4.74328158e-04,
#            4.74328158e-04,  4.74328158e-04,  4.74328158e-04,
#            4.74328158e-04,  4.74328158e-04,  4.74328158e-04,
#            4.74328158e-04,  4.74328158e-04,  1.55474328e-01,
#            4.65474328e-01,  7.75474328e-01,  1.01684690e+00,
#            1.12906650e+00,  1.16295837e+00,  1.17366945e+00,
#            1.17633570e+00]]),
#   array([[-6.59544115e-01,  2.84045493e+00,  6.34045397e+00,
#            9.84045301e+00,  1.33404521e+01,  1.68404511e+01,
#            2.03404501e+01,  2.38404492e+01,  2.73404482e+01,
#            3.08404473e+01,  3.43404463e+01,  3.78404453e+01,
#            4.13404444e+01,  4.48404434e+01,  4.83404425e+01,
#            5.18404415e+01,  5.53404406e+01,  5.88404396e+01,
#            6.21728163e+01,  6.50198857e+01,  6.71102284e+01,
#            6.86869350e+01,  7.01000767e+01,  7.14615180e+01,
#            7.28057463e+01],
#          [-2.95959095e-01, -2.93369822e-01, -2.90780549e-01,
#           -2.88191276e-01, -2.85602003e-01, -2.83012730e-01,
#           -2.80423457e-01, -2.77834184e-01, -2.75244911e-01,
#           -2.72655638e-01, -2.70066365e-01, -2.67477092e-01,
#           -2.64887819e-01, -2.62298546e-01, -2.59709273e-01,
#           -2.57120000e-01, -2.54530728e-01, -2.51941455e-01,
#            8.18229332e-01,  2.85395919e+00,  5.66117617e+00,
#            8.78591560e+00,  1.19879510e+01,  1.52123079e+01,
#            1.84438788e+01],
#          [ 1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            1.50000000e+01,  1.50000000e+01,  1.50000000e+01,
#            0.00000000e+00],
#          [ 7.39792345e-04,  7.39792345e-04,  7.39792345e-04,
#            7.39792345e-04,  7.39792345e-04,  7.39792345e-04,
#            7.39792345e-04,  7.39792345e-04,  7.39792345e-04,
#            7.39792345e-04,  7.39792345e-04,  7.39792345e-04,
#            7.39792345e-04,  7.39792345e-04,  7.39792345e-04,
#            7.39792345e-04,  7.39792345e-04,  1.55739792e-01,
#            4.65739792e-01,  7.75739792e-01,  1.01711236e+00,
#            1.12933197e+00,  1.16322383e+00,  1.17393491e+00,
#            1.17660116e+00]]),
#   array([[-6.79672797e-01,  2.82032494e+00,  6.32032268e+00,
#            9.82032042e+00,  1.33203182e+01,  1.68203159e+01,
#            2.03203136e+01,  2.38203114e+01,  2.73203091e+01,
#            3.08203069e+01,  3.43203046e+01,  3.78203023e+01,
#            4.13203001e+01,  4.48202978e+01,  4.83202956e+01,
#            5.18202933e+01,  5.53202910e+01,  5.88202888e+01,
#            6.21522409e+01,  6.49985028e+01,  6.70877322e+01,
#            6.86631996e+01,  7.00750715e+01,  7.14352342e+01,
#            7.27781809e+01],
#          [-2.95423439e-01, -2.91446321e-01, -2.87469202e-01,
#           -2.83492084e-01, -2.79514966e-01, -2.75537848e-01,
#           -2.71560730e-01, -2.67583612e-01, -2.63606494e-01,
#           -2.59629376e-01, -2.55652258e-01, -2.51675140e-01,
#           -2.47698022e-01, -2.43720904e-01, -2.39743786e-01,
#           -2.35766668e-01, -2.31789549e-01, -2.27812431e-01,
# ...
#   <__main__.State at 0x7f2a95fde9e8>,
#   <__main__.State at 0x7f2a95fde588>,
#   <__main__.State at 0x7f2a95fde0f0>,
#   <__main__.State at 0x7f2a95fde3c8>,
#   <__main__.State at 0x7f2a95fde4e0>,
#   <__main__.State at 0x7f2a95fdee10>,
#   <__main__.State at 0x7f2a95fde400>,
#   <__main__.State at 0x7f2a95fdeef0>,
#   <__main__.State at 0x7f2a95fde128>,
#   <__main__.State at 0x7f2a95fdeb38>,
#   <__main__.State at 0x7f2a95fdef60>,
#   <__main__.State at 0x7f2a95fde2b0>,
#   <__main__.State at 0x7f2a95fde080>,
#   <__main__.State at 0x7f2a95fde438>,
#   <__main__.State at 0x7f2a95fdeb00>,
#   <__main__.State at 0x7f2a95fdecf8>,
#   <__main__.State at 0x7f2a95fde780>,
#   <__main__.State at 0x7f2a95fdec50>,
#   <__main__.State at 0x7f2a95fde470>,
#   <__main__.State at 0x7f2a95fde710>,
#   <__main__.State at 0x7f2a95fde6d8>,
#   <__main__.State at 0x7f2a98d23390>,
#   <__main__.State at 0x7f2a98d23e48>,
#   <__main__.State at 0x7f2a98d239b0>,
#   <__main__.State at 0x7f2a98d23a90>,
#   <__main__.State at 0x7f2a98d23470>,
#   <__main__.State at 0x7f2a98d236a0>,
#   <__main__.State at 0x7f2a98d23908>,
#   <__main__.State at 0x7f2a98d23fd0>,
#   <__main__.State at 0x7f2a98d232e8>,
#   <__main__.State at 0x7f2a98d23278>,
#   <__main__.State at 0x7f2a98d23d68>,
#   <__main__.State at 0x7f2a98d23780>,
#   <__main__.State at 0x7f2a98d23e10>,
#   <__main__.State at 0x7f2a98d23d30>,
#   <__main__.State at 0x7f2a98d23048>,
#   <__main__.State at 0x7f2a98d23748>,
#   <__main__.State at 0x7f2a98d235f8>,
#   <__main__.State at 0x7f2a98d23198>,
#   <__main__.State at 0x7f2a98d23550>,
#   <__main__.State at 0x7f2a98d233c8>,
#   <__main__.State at 0x7f2a98d231d0>,
#   <__main__.State at 0x7f2a98d23160>,
#   <__main__.State at 0x7f2a98d235c0>,
#   <__main__.State at 0x7f2a98d23a20>,
#   <__main__.State at 0x7f2a98d23f28>,
#   <__main__.State at 0x7f2a98d23c18>,
#   <__main__.State at 0x7f2a98d23358>,
#   <__main__.State at 0x7f2a98d23320>,
#   <__main__.State at 0x7f2a98d23630>,
#   <__main__.State at 0x7f2a98d23be0>,
#   <__main__.State at 0x7f2a98d23b00>,
#   <__main__.State at 0x7f2a98d23240>,
#   <__main__.State at 0x7f2a98d23588>,
#   <__main__.State at 0x7f2a98d234e0>,
#   <__main__.State at 0x7f2a98d23860>,
#   <__main__.State at 0x7f2a98d237b8>,
#   <__main__.State at 0x7f2a98d230f0>,
#   <__main__.State at 0x7f2a98d23ba8>,
#   <__main__.State at 0x7f2a98d23f98>,
#   <__main__.State at 0x7f2a98d237f0>,
#   <__main__.State at 0x7f2a98d23b38>,
#   <__main__.State at 0x7f2a98d236d8>,
#   <__main__.State at 0x7f2a98d23a58>,
#   <__main__.State at 0x7f2a98d23080>,
#   <__main__.State at 0x7f2a98d23f60>,
#   <__main__.State at 0x7f2a98d23400>,
#   <__main__.State at 0x7f2a98d23438>,
#   <__main__.State at 0x7f2a98d23710>,
#   <__main__.State at 0x7f2a98d23518>,
#   <__main__.State at 0x7f2a98d23c88>,
#   <__main__.State at 0x7f2a98d238d0>,
#   <__main__.State at 0x7f2a98d23128>,
#   <__main__.State at 0x7f2a98d23668>,
#   <__main__.State at 0x7f2a98d23cf8>,
#   <__main__.State at 0x7f2a98d232b0>,
#   <__main__.State at 0x7f2a98d23e80>,
#   <__main__.State at 0x7f2a98d239e8>,
#   <__main__.State at 0x7f2a98d23ac8>,
#   <__main__.State at 0x7f2a98d23dd8>,
#   <__main__.State at 0x7f2a98d23940>,
#   <__main__.State at 0x7f2a98d23828>,
#   <__main__.State at 0x7f2a961811d0>,
#   <__main__.State at 0x7f2a96181828>,
#   <__main__.State at 0x7f2a96181128>,
#   <__main__.State at 0x7f2a961812e8>,
#   <__main__.State at 0x7f2a961818d0>,
#   <__main__.State at 0x7f2a96181320>,
#   <__main__.State at 0x7f2a96181d68>,
#   <__main__.State at 0x7f2a961813c8>,
#   <__main__.State at 0x7f2a96181f60>,
#   <__main__.State at 0x7f2a96181240>,
#   <__main__.State at 0x7f2a96181898>,
#   <__main__.State at 0x7f2a96181f98>,
#   <__main__.State at 0x7f2a96181470>,
#   <__main__.State at 0x7f2a96181a20>,
#   <__main__.State at 0x7f2a96181b70>,
#   <__main__.State at 0x7f2a961819e8>,
#   <__main__.State at 0x7f2a96181e10>,
#   <__main__.State at 0x7f2a961810f0>,
#   <__main__.State at 0x7f2a96181d30>,
#   <__main__.State at 0x7f2a96181518>,
#   <__main__.State at 0x7f2a96181fd0>,
#   <__main__.State at 0x7f2a961816d8>,
#   <__main__.State at 0x7f2a96181940>,
#   <__main__.State at 0x7f2a961815c0>,
#   <__main__.State at 0x7f2a96181a58>,
#   <__main__.State at 0x7f2a961812b0>,
#   <__main__.State at 0x7f2a96181198>,
#   <__main__.State at 0x7f2a96181710>,
#   <__main__.State at 0x7f2a96181da0>,
#   <__main__.State at 0x7f2a96181cf8>,
#   <__main__.State at 0x7f2a961817b8>,
#   <__main__.State at 0x7f2a96181eb8>,
#   <__main__.State at 0x7f2a961819b0>,
#   <__main__.State at 0x7f2a96181780>,
#   <__main__.State at 0x7f2a96181358>,
#   <__main__.State at 0x7f2a96181ac8>,
#   <__main__.State at 0x7f2a96181be0>,
#   <__main__.State at 0x7f2a96181e48>,
#   <__main__.State at 0x7f2a96181208>,
#   <__main__.State at 0x7f2a96181908>,
#   <__main__.State at 0x7f2a96181c88>,
#   <__main__.State at 0x7f2a96181a90>,
#   <__main__.State at 0x7f2a96181ef0>,
#   <__main__.State at 0x7f2a96181588>,
#   <__main__.State at 0x7f2a961814a8>,
#   <__main__.State at 0x7f2a96181630>,
#   <__main__.State at 0x7f2a96181978>,
#   <__main__.State at 0x7f2a96181080>,
#   <__main__.State at 0x7f2a96181e80>,
#   <__main__.State at 0x7f2a961817f0>,
#   <__main__.State at 0x7f2a961815f8>,
#   <__main__.State at 0x7f2a96181860>,
#   <__main__.State at 0x7f2a96181748>,
#   <__main__.State at 0x7f2a961816a0>,
#   <__main__.State at 0x7f2a96181ba8>,
#   <__main__.State at 0x7f2a96181dd8>,
#   <__main__.State at 0x7f2a96181cc0>,
#   <__main__.State at 0x7f2a96181b00>,
#   <__main__.State at 0x7f2a961810b8>,
#   <__main__.State at 0x7f2a98d6fa58>,
#   <__main__.State at 0x7f2a98d6fb00>,
#   <__main__.State at 0x7f2a98d6f630>,
#   <__main__.State at 0x7f2a98d6ffd0>,
#   <__main__.State at 0x7f2a98d6f240>,
#   <__main__.State at 0x7f2a98d6f518>,
#   <__main__.State at 0x7f2a98d6f828>,
#   <__main__.State at 0x7f2a98d6f898>,
#   <__main__.State at 0x7f2a98d6fba8>,
#   <__main__.State at 0x7f2a98d6f208>,
#   <__main__.State at 0x7f2a98d6fd30>,
#   <__main__.State at 0x7f2a98d6f940>,
#   <__main__.State at 0x7f2a98d6f860>,
#   <__main__.State at 0x7f2a98d6feb8>,
#   <__main__.State at 0x7f2a98d6fac8>,
#   <__main__.State at 0x7f2a98d6f4e0>,
#   <__main__.State at 0x7f2a98d6ff60>,
#   <__main__.State at 0x7f2a98d6f588>,
#   <__main__.State at 0x7f2a98d6f6a0>,
#   <__main__.State at 0x7f2a98d6f400>,
#   <__main__.State at 0x7f2a98d6f908>,
#   <__main__.State at 0x7f2a98d6f780>,
#   <__main__.State at 0x7f2a98d6ff28>,
#   <__main__.State at 0x7f2a98d6fdd8>,
#   <__main__.State at 0x7f2a98d6fcf8>,
#   <__main__.State at 0x7f2a98d6f160>,
#   <__main__.State at 0x7f2a98d6fa90>,
#   <__main__.State at 0x7f2a98d6ff98>,
#   <__main__.State at 0x7f2a98d6fbe0>,
#   <__main__.State at 0x7f2a98d6f2e8>,
#   <__main__.State at 0x7f2a98d6f390>,
#   <__main__.State at 0x7f2a98d6f278>,
#   <__main__.State at 0x7f2a98d6f2b0>,
#   <__main__.State at 0x7f2a98d6f9e8>,
#   <__main__.State at 0x7f2a98d6f1d0>,
#   <__main__.State at 0x7f2a98d6f320>,
#   <__main__.State at 0x7f2a98d6f438>,
#   <__main__.State at 0x7f2a98d6f3c8>,
#   <__main__.State at 0x7f2a98d6f198>,
#   <__main__.State at 0x7f2a98d6fe48>,
#   <__main__.State at 0x7f2a98d6f5f8>,
#   <__main__.State at 0x7f2a98d6f6d8>,
#   <__main__.State at 0x7f2a98d6fc50>,
#   <__main__.State at 0x7f2a98d6f7b8>,
#   <__main__.State at 0x7f2a98d6fef0>,
#   <__main__.State at 0x7f2a98d6f978>,
#   <__main__.State at 0x7f2a98d6f710>,
#   <__main__.State at 0x7f2a98d6f550>,
#   <__main__.State at 0x7f2a98d6f0b8>,
#   <__main__.State at 0x7f2a98d6f358>,
#   <__main__.State at 0x7f2a98d6f128>,
#   <__main__.State at 0x7f2a98d6f048>,
#   <__main__.State at 0x7f2a98d6fa20>,
#   <__main__.State at 0x7f2a98d6fc18>,
#   <__main__.State at 0x7f2a98d6f9b0>,
#   <__main__.State at 0x7f2a98d6fd68>,
#   <__main__.State at 0x7f2a98d6fda0>,
#   <__main__.State at 0x7f2a98d6fb70>,
#   <__main__.State at 0x7f2a98d6f470>,
#   <__main__.State at 0x7f2a98d6f0f0>,
#   <__main__.State at 0x7f2a98d6fb38>,
#   <__main__.State at 0x7f2a959d4748>,
#   <__main__.State at 0x7f2a959d4be0>,
#   <__main__.State at 0x7f2a959d4048>,
#   <__main__.State at 0x7f2a959d4860>,
#   <__main__.State at 0x7f2a959d4940>,
#   <__main__.State at 0x7f2a959d4668>,
#   <__main__.State at 0x7f2a959d4320>,
#   <__main__.State at 0x7f2a959d4898>,
#   <__main__.State at 0x7f2a959d49b0>,
#   <__main__.State at 0x7f2a959d44a8>,
#   <__main__.State at 0x7f2a959d4160>,
#   <__main__.State at 0x7f2a959d4b38>,
#   <__main__.State at 0x7f2a959d4208>,
#   <__main__.State at 0x7f2a959d4198>,
#   <__main__.State at 0x7f2a959d4e80>,
#   <__main__.State at 0x7f2a959d4c88>,
#   <__main__.State at 0x7f2a959d4978>,
#   <__main__.State at 0x7f2a959d4c18>,
#   <__main__.State at 0x7f2a959d4390>,
#   <__main__.State at 0x7f2a959d4828>,
#   <__main__.State at 0x7f2a959d4f98>,
#   <__main__.State at 0x7f2a959d4fd0>,
#   <__main__.State at 0x7f2a959d4ef0>,
#   <__main__.State at 0x7f2a959d4470>,
#   <__main__.State at 0x7f2a959d4da0>,
#   <__main__.State at 0x7f2a959d4080>,
#   <__main__.State at 0x7f2a959d45f8>,
#   <__main__.State at 0x7f2a959d4a90>,
#   <__main__.State at 0x7f2a959d4400>,
#   <__main__.State at 0x7f2a959d40f0>,
#   <__main__.State at 0x7f2a959d4ba8>,
#   <__main__.State at 0x7f2a959d4128>,
#   <__main__.State at 0x7f2a959d4a20>,
#   <__main__.State at 0x7f2a959d4eb8>,
#   <__main__.State at 0x7f2a959d46a0>,
#   <__main__.State at 0x7f2a959d4588>,
#   <__main__.State at 0x7f2a959d4d68>,
#   <__main__.State at 0x7f2a959d43c8>,
#   <__main__.State at 0x7f2a959d4d30>,
#   <__main__.State at 0x7f2a959d4518>,
#   <__main__.State at 0x7f2a959d49e8>,
#   <__main__.State at 0x7f2a959d4f28>,
#   <__main__.State at 0x7f2a959d4e10>,
#   <__main__.State at 0x7f2a959d41d0>,
#   <__main__.State at 0x7f2a959d44e0>,
#   <__main__.State at 0x7f2a959d4b00>,
#   <__main__.State at 0x7f2a959d4a58>,
#   <__main__.State at 0x7f2a959d4e48>,
#   <__main__.State at 0x7f2a959d47b8>,
#   <__main__.State at 0x7f2a959d40b8>,
#   <__main__.State at 0x7f2a959d45c0>,
#   <__main__.State at 0x7f2a959d4908>,
#   <__main__.State at 0x7f2a959d4240>,
#   <__main__.State at 0x7f2a98c8c668>,
#   <__main__.State at 0x7f2a98c8c780>,
#   <__main__.State at 0x7f2a98c8cb70>,
#   <__main__.State at 0x7f2a98c8cb00>,
#   <__main__.State at 0x7f2a98c8cc50>,
#   <__main__.State at 0x7f2a98c8cf98>,
#   <__main__.State at 0x7f2a98c8c470>,
#   <__main__.State at 0x7f2a98c8c6d8>,
#   <__main__.State at 0x7f2a98c8cc18>,
#   <__main__.State at 0x7f2a98c8cac8>,
#   <__main__.State at 0x7f2a98c8c3c8>,
#   <__main__.State at 0x7f2a98c8cf60>,
#   <__main__.State at 0x7f2a98c8c198>,
#   <__main__.State at 0x7f2a98c8c860>,
#   <__main__.State at 0x7f2a98c8c978>,
#   <__main__.State at 0x7f2a98c8c080>,
#   <__main__.State at 0x7f2a98c8c940>,
#   <__main__.State at 0x7f2a98c8c898>,
#   <__main__.State at 0x7f2a98c8ca20>,
#   <__main__.State at 0x7f2a98c8c588>,
#   <__main__.State at 0x7f2a98c8c630>,
#   <__main__.State at 0x7f2a98c8c828>,
#   <__main__.State at 0x7f2a98c8c518>,
#   <__main__.State at 0x7f2a98c8c550>,
#   <__main__.State at 0x7f2a98c8c5c0>,
#   <__main__.State at 0x7f2a98c8c4e0>,
#   <__main__.State at 0x7f2a98c8c908>,
#   <__main__.State at 0x7f2a98c8ce48>,
#   <__main__.State at 0x7f2a98c8cd68>,
#   <__main__.State at 0x7f2a98c8ca58>,
#   <__main__.State at 0x7f2a98c8ce10>,
#   <__main__.State at 0x7f2a98c8c278>,
#   <__main__.State at 0x7f2a98c8c390>,
#   <__main__.State at 0x7f2a98c8c0f0>,
#   <__main__.State at 0x7f2a98c8c9e8>,
#   <__main__.State at 0x7f2a98c8c748>,
#   <__main__.State at 0x7f2a98c8c7f0>,
#   <__main__.State at 0x7f2a98c8cba8>,
#   <__main__.State at 0x7f2a98c8c0b8>,
#   <__main__.State at 0x7f2a98c8c240>,
#   <__main__.State at 0x7f2a98c8cb38>,
#   <__main__.State at 0x7f2a98c8c208>,
#   <__main__.State at 0x7f2a98c8cc88>,
#   <__main__.State at 0x7f2a98c8c358>,
#   <__main__.State at 0x7f2a98c8c9b0>,
#   <__main__.State at 0x7f2a98c8c1d0>,
#   <__main__.State at 0x7f2a98c8c7b8>,
#   <__main__.State at 0x7f2a98c8c128>,
#   <__main__.State at 0x7f2a98c8c8d0>,
#   <__main__.State at 0x7f2a98c8cda0>,
#   <__main__.State at 0x7f2a98c8ccc0>,
#   <__main__.State at 0x7f2a98c8ccf8>,
#   <__main__.State at 0x7f2a98c8c400>,
#   <__main__.State at 0x7f2a98c8c6a0>,
#   <__main__.State at 0x7f2a98c8c438>,
#   <__main__.State at 0x7f2a98c8cfd0>,
#   <__main__.State at 0x7f2a98c8cbe0>,
#   <__main__.State at 0x7f2a98c8c160>,
#   <__main__.State at 0x7f2a98c8ce80>,
#   <__main__.State at 0x7f2a98c8cd30>,
#   <__main__.State at 0x7f2a98c8ca90>,
#   <__main__.State at 0x7f2a98c8cef0>,
#   <__main__.State at 0x7f2a98c8c710>,
#   <__main__.State at 0x7f2a98c8c5f8>,
#   <__main__.State at 0x7f2a98c8c320>,
#   <__main__.State at 0x7f2a98ee2f60>,
#   <__main__.State at 0x7f2a98ee2320>,
#   <__main__.State at 0x7f2a98ee2ef0>,
#   <__main__.State at 0x7f2a98ee2550>,
#   <__main__.State at 0x7f2a98ee29b0>,
#   <__main__.State at 0x7f2a98ee24a8>,
#   <__main__.State at 0x7f2a98ee29e8>,
#   <__main__.State at 0x7f2a98ee2a58>,
#   <__main__.State at 0x7f2a98ee2f98>,
#   <__main__.State at 0x7f2a98ee2cc0>,
#   <__main__.State at 0x7f2a98ee21d0>,
#   <__main__.State at 0x7f2a98ee22b0>,
#   <__main__.State at 0x7f2a98ee2898>,
#   <__main__.State at 0x7f2a98ee25f8>,
#   <__main__.State at 0x7f2a98ee2400>,
#   <__main__.State at 0x7f2a98ee26d8>,
#   <__main__.State at 0x7f2a98ee2358>,
#   <__main__.State at 0x7f2a98ee2710>,
#   <__main__.State at 0x7f2a98ee2080>,
#   <__main__.State at 0x7f2a98ee2588>,
#   <__main__.State at 0x7f2a98ee2940>,
#   <__main__.State at 0x7f2a98ee2048>,
#   <__main__.State at 0x7f2a98ee20f0>,
#   <__main__.State at 0x7f2a98ee2ba8>,
#   <__main__.State at 0x7f2a98ee2e80>,
#   <__main__.State at 0x7f2a98ee2d30>,
#   <__main__.State at 0x7f2a98ee2e10>,
#   <__main__.State at 0x7f2a98ee2208>,
#   <__main__.State at 0x7f2a98ee2eb8>,
#   <__main__.State at 0x7f2a98ee2a20>,
#   <__main__.State at 0x7f2a98ee2748>,
#   <__main__.State at 0x7f2a98ee2b38>,
#   <__main__.State at 0x7f2a98ee2da0>,
#   <__main__.State at 0x7f2a98ee24e0>,
#   <__main__.State at 0x7f2a98ee26a0>,
#   <__main__.State at 0x7f2a98ee2b00>,
#   <__main__.State at 0x7f2a98ee22e8>,
#   <__main__.State at 0x7f2a98ee2f28>,
#   <__main__.State at 0x7f2a98ee2fd0>,
#   <__main__.State at 0x7f2a98ee2470>,
#   <__main__.State at 0x7f2a98ee2978>,
#   <__main__.State at 0x7f2a98ee2278>,
#   <__main__.State at 0x7f2a98ee2c50>,
#   <__main__.State at 0x7f2a98ee2d68>,
#   <__main__.State at 0x7f2a98ee2c88>,
#   <__main__.State at 0x7f2a98ee2be0>,
#   <__main__.State at 0x7f2a98ee2390>,
#   <__main__.State at 0x7f2a98ee2ac8>,
#   <__main__.State at 0x7f2a98ee2438>,
#   <__main__.State at 0x7f2a98ee2128>,
#   <__main__.State at 0x7f2a98ee2160>,
#   <__main__.State at 0x7f2a98ee2828>,
#   <__main__.State at 0x7f2a98ee2668>,
#   <__main__.State at 0x7f2a98ee2cf8>,
#   <__main__.State at 0x7f2a98ee2198>,
#   <__main__.State at 0x7f2a95ff49e8>,
#   <__main__.State at 0x7f2a95ff42e8>,
#   <__main__.State at 0x7f2a95ff4710>,
#   <__main__.State at 0x7f2a95ff49b0>,
#   <__main__.State at 0x7f2a95ff4b38>,
#   <__main__.State at 0x7f2a95ff46a0>,
#   <__main__.State at 0x7f2a95ff4e10>,
#   <__main__.State at 0x7f2a95ff4208>,
#   <__main__.State at 0x7f2a95ff4748>,
#   <__main__.State at 0x7f2a95ff4828>,
#   <__main__.State at 0x7f2a95ff4860>,
#   <__main__.State at 0x7f2a95ff4fd0>,
#   <__main__.State at 0x7f2a95ff41d0>,
#   <__main__.State at 0x7f2a95ff4c50>,
#   <__main__.State at 0x7f2a95ff4ba8>,
#   <__main__.State at 0x7f2a95ff4390>,
#   <__main__.State at 0x7f2a95ff4be0>,
#   <__main__.State at 0x7f2a95ff4cf8>,
#   <__main__.State at 0x7f2a95ff4668>,
#   <__main__.State at 0x7f2a95ff4940>,
#   <__main__.State at 0x7f2a95ff4240>,
#   <__main__.State at 0x7f2a95ff4320>,
#   <__main__.State at 0x7f2a95ff47b8>,
#   <__main__.State at 0x7f2a95ff4550>,
#   <__main__.State at 0x7f2a95ff4dd8>,
#   <__main__.State at 0x7f2a95ff4da0>,
#   <__main__.State at 0x7f2a95ff46d8>,
#   <__main__.State at 0x7f2a95ff4e48>,
#   <__main__.State at 0x7f2a95ff4f28>,
#   <__main__.State at 0x7f2a95ff4cc0>,
#   <__main__.State at 0x7f2a95ff4c18>,
#   <__main__.State at 0x7f2a95ff4a58>,
#   <__main__.State at 0x7f2a95ff4b70>,
#   <__main__.State at 0x7f2a95ff43c8>,
#   <__main__.State at 0x7f2a95ff4ef0>,
#   <__main__.State at 0x7f2a95ff45f8>,
#   <__main__.State at 0x7f2a95ff4128>,
#   <__main__.State at 0x7f2a95ff44a8>,
#   <__main__.State at 0x7f2a95ff44e0>,
#   <__main__.State at 0x7f2a95ff4978>,
#   <__main__.State at 0x7f2a95ff4e80>,
#   <__main__.State at 0x7f2a95ff4a20>,
#   <__main__.State at 0x7f2a95ff4f98>,
#   <__main__.State at 0x7f2a95ff4358>,
#   <__main__.State at 0x7f2a95ff4780>,
#   <__main__.State at 0x7f2a95ff4518>]}

# %%
np.arctan2(1,1)

# %%
#%matplotlib inline
plt.plot(cx,cy)
plt.show()

# %%
plt.plot(range(len(cyaw)),cyaw)
plt.show()

# %%
dcx=np.gradient(cx)
dcy=np.gradient(cy)
cyaw=[np.arctan2(y,x) for x,y in zip(dcx,dcy)]

# %%
cx, cy, cyaw, ck, s = cubic_spline_planner.calc_spline_course(tx,ty,ds=dl)
yaw0=np.deg2rad(90)
cyaw=[yaw-yaw0 for yaw in cyaw]

# %%
import numpy as np
np.rad2deg(2.64)

# %%
cyaw

# %%
import cvxpy as cp
import numpy as np

# Problem data.
m = 1
n = 1
np.random.seed(1)
A = 10#np.random.randn(m, n)
b = 5#np.random.randn(m)

# Construct the problem.
x = cp.Variable(n)
objective = cp.Minimize(cp.sum_squares(A*x - b))
constraints = [0 <= x, x <= 1]
prob = cp.Problem(objective, constraints)

# The optimal objective value is returned by `prob.solve()`.
result = prob.solve()
# The optimal value for x is stored in `x.value`.
print(x.value)
# The optimal Lagrange multiplier for a constraint is stored in
# `constraint.dual_value`.
print(constraints[0].dual_value)

# %%
print(x.value)

# %%
x=np.array(range(0,100))
x=x/100

# %%
y=10*x-5
y=np.square(y)
plt.plot(x,y)
plt.show()

# %%
import gym
gym.make('CarRacing-v0')
