# %%
#!pip3 install PyAutoGUI
#!sudo apt-get install scrot
#os.system('pkill torcs')

# %%
def laser_to_xy(sleft,sright,ang):
    X=sright*np.cos(ang)+sleft*np.cos(ang)
    X=X/2.0
    width=sright*np.sin(ang)+sleft*np.sin(angl)
    centreY=width/2.0
    Y=sright*np.sin(ang)-width
    return X,Y

# %%
import sys,os
sys.path.append("../gym_torcs-root/")
#from gym_torcs import TorcsEnv
from sample_agent import Agent
import numpy as np
from snakeoil_v1 import Client_v1,drive_example
import pyautogui as pg
import time
import pyautogui as pg
from matplotlib import pyplot as plt
import cv2
from collections import deque
#import pygetwindow as gw

# %%
# %matplotlib tk
C= Client_v1(p=3101,vision=False,jupyter=True)
C.R.d['steer']=0
C.R.d['gas']=0
C.respond_to_server()
win=np.ones((64,64,3),dtype=np.uint8)
#ims=plt.imshow(img)
#plt.show()
def press(event):
    print('press', event.key)
    sys.stdout.flush()
def init_plot():
    #fig = plt.figure(nro)
    fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(10,6))
    fig.canvas.mpl_connect('key_press_event', press)
    plt.ion()
    fig.show()
    return plt,fig,axes
#plt,fig,axes=init_plot()
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(10,6))
fig.canvas.mpl_connect('key_press_event', press)
plt.ion()
fig.show()

#plt.show()
#axes.clear()
tc_q=deque(maxlen=10)
for i in range(1000):
#if 1==1:
        C.get_servers_input()
        time.sleep(.1)
        #print("got input ...")
        tc=C.S.d['track']
        #img1=np.array(img,dtype=np.uint8)
        #img1=img1.reshape(64,64,3)
        tcs=tc[0:5]+tc[-5:]
        tc_q.append(tcs)
        temp_q=np.array(tc_q)
        for ax1,ax2 in zip(axes[0],axes[1]):
            ax1.clear()
            ax2.clear()
        #temp_x,temp_y=laser_to_xy()
        axes[0,0].plot(temp_q[:,:5])
        axes[1,0].plot(temp_q[:,-5:])
        
        fig.canvas.draw()
        #plt.show()


        print('plotted...',tc[0],tc[-1])
        #drive_example(C)
        #steer=int(input('steer :'))
        #gas=float(input('gas : '))
        steer=np.deg2rad(steer)
        C.R.d['steer']=steer
        C.R.d['gas']=gas
        C.respond_to_server()
plt.show()
#plt.show()






#plt.ioff()
#C.shutdown()
# Out:
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# ('127.0.0.1', 3101) ***identified***
# done
# plotted... 7.48438 7.94949
# plotted... 7.48065 7.95152
# plotted... 7.47763 7.95629
# plotted... 7.47651 7.95696
# plotted... 7.474 7.95883
# plotted... 7.47101 7.95921
# plotted... 7.46834 7.95897
# plotted... 7.46675 7.9547
# plotted... 7.46556 7.9492
# plotted... 7.46566 7.94121
# plotted... 7.46687 7.93169
# plotted... 7.46964 7.92034
# plotted... 7.47497 7.90387
# plotted... 7.48283 7.88477
# plotted... 7.49423 7.86084
# plotted... 7.51036 7.83204
# plotted... 7.53113 7.79813
# plotted... 7.55762 7.75858
# plotted... 7.59101 7.71176
# plotted... 7.63224 7.65772
# plotted... 7.68237 7.59467
# plotted... 7.74204 7.52309
# plotted... 7.81265 7.44167
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6cbf1d654f90> in <module>
#      36         for ax1,ax2 in zip(axes[0],axes[1]):
#      37             ax1.clear()
# ---> 38             ax2.clear()
#      39         #temp_x,temp_y=laser_to_xy()
#      40         axes[0,0].plot(temp_q[:,:5])
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in clear(self)
#    1116     def clear(self):
#    1117         """Clear the axes."""
# -> 1118         self.cla()
#    1119
#    1120     def get_facecolor(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in cla(self)
#     978
#     979         for name, spine in self.spines.items():
# --> 980             spine.cla()
#     981
#     982         self.ignore_existing_data_limits = True
#
# ~/.local/lib/python3.6/site-packages/matplotlib/spines.py in cla(self)
#     178         self._position = None  # clear position
#     179         if self.axis is not None:
# --> 180             self.axis.cla()
#     181
#     182     def is_frame_like(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in cla(self)
#     811                              rcParams['axes.grid.which'] in ('both', 'minor'))
#     812
# --> 813         self.reset_ticks()
#     814
#     815         self.converter = None
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in reset_ticks(self)
#     834             pass
#     835         try:
# --> 836             self.set_clip_path(self.axes.patch)
#     837         except AttributeError:
#     838             pass
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     923     def set_clip_path(self, clippath, transform=None):
#     924         artist.Artist.set_clip_path(self, clippath, transform)
# --> 925         for child in self.majorTicks + self.minorTicks:
#     926             child.set_clip_path(clippath, transform)
#     927         self.stale = True
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     675             if self._major:
#     676                 instance.majorTicks = []
# --> 677                 tick = instance._get_tick(major=True)
#     678                 instance.majorTicks.append(tick)
#     679                 return instance.majorTicks
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1816         else:
#    1817             tick_kw = self._minor_tick_kw
# -> 1818         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1819
#    1820     def _get_label(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     178         self.label1 = self._get_text1()
#     179         self.label = self.label1  # legacy name
# --> 180         self.label2 = self._get_text2()
#     181
#     182         self.gridOn = gridOn
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _get_text2(self)
#     456             color=self._labelcolor,
#     457             verticalalignment=vert,
# --> 458             horizontalalignment=horiz,
#     459             )
#     460         t.set_transform(trans)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     150         """
#     151
# --> 152         Artist.__init__(self)
#     153         self._x, self._y = x, y
#     154
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in __init__(self)
#     112         self._gid = None
#     113         self._snap = None
# --> 114         self._sketch = rcParams['path.sketch']
#     115         self._path_effects = rcParams['path.effects']
#     116         self._sticky_edges = _XYPair([], [])
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in __getitem__(self, key)
#     892                 plt.switch_backend(rcsetup._auto_backend_sentinel)
#     893
# --> 894         return dict.__getitem__(self, key)
#     895
#     896     def __repr__(self):
#
# KeyboardInterrupt:

# %%
def press(event):
    print('press', event.key)
    sys.stdout.flush()
    
img=np.ones((64,64,3),dtype=np.uint8)
fig,ax=plt.subplots()
fig.canvas.mpl_connect('key_press_event', press)
ax.plot([1,2,3,4,5])
plt.show()
# Out:
# press a
# press a
# press a
# press a
# press a
# press a
# press n
# press n
# press n
# press n
# press n

# %%
image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
cv2.imshow('img',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
vision = True
episode_count = 10
max_steps = 50
reward = 0
done = False
step = 0

# Generate a Torcs environment
env = TorcsEnv(vision=vision, throttle=False,jupyter=True)

agent = Agent(1)  # steering only


print("TORCS Experiment Start.")
for i in range(episode_count):
    print("Episode : " + str(i))

    if np.mod(i, 3) == 0:
        # Sometimes you need to relaunch TORCS because of the memory leak error
        ob = env.reset(relaunch=True)
    else:
        ob = env.reset()

    total_reward = 0.
    for j in range(max_steps):
        action = agent.act(ob, reward, done, vision)

        ob, reward, done, _ = env.step(action)
        #print(ob)
        total_reward += reward

        step += 1
        if done:
            break

    print("TOTAL REWARD @ " + str(i) +" -th Episode  :  " + str(total_reward))
    print("Total Step: " + str(step))
    print("")

env.end()  # This is for shutting down TORCS
print("Finish.")
# Out:
# TORCS Experiment Start.
# Episode : 0
# loop
# Waiting for server on 3101............
# Count Down : 5
# loop
# ('127.0.0.1', 3101) ***identified***
# Client connected on 3101..............
# done
# (31, 3)
# (31, 3)
# (32, 3)
# (31, 3)
# (32, 3)
# (29, 3)
# (31, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (29, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (31, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (37, 3)
# (42, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (42, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (42, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (43, 3)
# (42, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (42, 3)
# (35, 3)
# (32, 3)
# TOTAL REWARD @ 0 -th Episode  :  758.5256545746887
# Total Step: 50
#
# Episode : 1
# loop
# Waiting for server on 3101............
# Count Down : 5
# loop
# ('127.0.0.1', 3101) ***identified***
# Client connected on 3101..............
# done
# (31, 3)
# (30, 3)
# (30, 3)
# (31, 3)
# (31, 3)
# (30, 3)
# (31, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (33, 3)
# (34, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (31, 3)
# (33, 3)
# (37, 3)
# (37, 3)
# (41, 3)
# (43, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (42, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (42, 3)
# (42, 3)
# (42, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (43, 3)
# (42, 3)
# TOTAL REWARD @ 1 -th Episode  :  598.0022360650682
# Total Step: 100
#
# Episode : 2
# loop
# Waiting for server on 3101............
# Count Down : 5
# loop
# ('127.0.0.1', 3101) ***identified***
# Client connected on 3101..............
# done
# (31, 3)
# (31, 3)
# (31, 3)
# (31, 3)
# (32, 3)
# (29, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (34, 3)
# (41, 3)
# (43, 3)
# (43, 3)
# (43, 3)
# (42, 3)
# (40, 3)
# (43, 3)
# (43, 3)
# (42, 3)
# TOTAL REWARD @ 2 -th Episode  :  677.2401601313983
# Total Step: 150
#
# Episode : 3
# ### TORCS is RELAUNCHED ###
# loop
# Waiting for server on 3101............
# Count Down : 5
# loop
# Waiting for server on 3101............
# Count Down : 4
# loop
# Waiting for server on 3101............
# Count Down : 3
# loop
# Waiting for server on 3101............
# Count Down : 2
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# loop
# Waiting for server on 3101............
# Count Down : 4
# loop
# Waiting for server on 3101............
# Count Down : 3
# loop
# Waiting for server on 3101............
# Count Down : 2
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# loop
# Waiting for server on 3101............
# Count Down : 4
# loop
# Waiting for server on 3101............
# Count Down : 3
# loop
# Waiting for server on 3101............
# Count Down : 2
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# loop
# Waiting for server on 3101............
# Count Down : 4
# loop
# Waiting for server on 3101............
# Count Down : 3
# loop
# Waiting for server on 3101............
# Count Down : 2
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-77d169c5902c> in <module>
#      18     if np.mod(i, 3) == 0:
#      19         # Sometimes you need to relaunch TORCS because of the memory leak error
# ---> 20         ob = env.reset(relaunch=True)
#      21     else:
#      22         ob = env.reset()
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/gym_torcs.py in reset(self, relaunch)
#     184
#     185         # Modify here if you use multiple tracks in the environment
# --> 186         self.client = snakeoil3.Client(p=3101, vision=self.vision,jupyter=self.jupyter)  # Open new UDP in vtorcs
#     187         self.client.MAX_STEPS = np.inf
#     188
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/snakeoil3_gym.py in __init__(self, H, p, i, e, t, s, d, vision, jupyter)
#     140         self.S= ServerState()
#     141         self.R= DriverAction()
# --> 142         self.setup_connection()
#     143         print("done")
#     144     def setup_connection(self):
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/snakeoil3_gym.py in setup_connection(self)
#     167             sockdata= str()
#     168             try:
# --> 169                 sockdata,addr= self.so.recvfrom(data_size)
#     170                 sockdata = sockdata.decode('utf-8')
#     171                 print(addr,sockdata)
#
# KeyboardInterrupt:

# %%
env = TorcsEnv(vision=True, throttle=False,jupyter=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-87e31126fcc1> in <module>
# ----> 1 env = TorcsEnv(vision=True, throttle=False,jupyter=True)
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/gym_torcs.py in __init__(self, vision, throttle, gear_change, jupyter)
#      37             os.system('sh autostart.sh')
#      38         else:
# ---> 39             start()
#      40         time.sleep(0.5)
#      41
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/st.py in start()
#       2 import time
#       3 def start():
# ----> 4     os.system('pkill torcs')
#       5     os.system('torcs -nofuel -nodamage -nolaptime -vision &')
#       6     time.sleep(1)
#
# NameError: name 'os' is not defined

# %%
vision = True
episode_count = 10
max_steps = 50
reward = 0
done = False
step = 0

# Generate a Torcs environment
env = TorcsEnv(vision=vision, throttle=False)

agent = Agent(1)  # steering only

# %%
ob = env.reset(relaunch=True)
ob

# %%
ob
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6b700ec508d9> in <module>
# ----> 1 ob
#
# NameError: name 'ob' is not defined

# %%
print("TORCS Experiment Start.")
for i in range(episode_count):
    print("Episode : " + str(i))

    if np.mod(i, 3) == 0:
        # Sometimes you need to relaunch TORCS because of the memory leak error
        ob = env.reset(relaunch=True)
    else:
        ob = env.reset()

    total_reward = 0.
    for j in range(max_steps):
        action = agent.act(ob, reward, done, vision)

        ob, reward, done, _ = env.step(action)
        #print(ob)
        total_reward += reward

        step += 1
        if done:
            break

    print("TOTAL REWARD @ " + str(i) +" -th Episode  :  " + str(total_reward))
    print("Total Step: " + str(step))
    print("")

env.end()  # This is for shutting down TORCS
print("Finish.")
# Out:
# TORCS Experiment Start.
# Episode : 0
# Waiting for server on 3101............
# Count Down : 5
# Waiting for server on 3101............
# Count Down : 4
# Waiting for server on 3101............
# Count Down : 3
# Waiting for server on 3101............
# Count Down : 2
# Waiting for server on 3101............
# Count Down : 1
# Waiting for server on 3101............
# Count Down : 0
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# Waiting for server on 3101............
# Count Down : 4
# Waiting for server on 3101............
# Count Down : 3
# Waiting for server on 3101............
# Count Down : 2
# Waiting for server on 3101............
# Count Down : 1
# Waiting for server on 3101............
# Count Down : 0
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# Waiting for server on 3101............
# Count Down : 4
# Waiting for server on 3101............
# Count Down : 3
# Waiting for server on 3101............
# Count Down : 2
# Waiting for server on 3101............
# Count Down : 1
# Waiting for server on 3101............
# Count Down : 0
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# Waiting for server on 3101............
# Count Down : 4
# Waiting for server on 3101............
# Count Down : 3
# Waiting for server on 3101............
# Count Down : 2
# Waiting for server on 3101............
# Count Down : 1
# Waiting for server on 3101............
# Count Down : 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ed10df93e941> in <module>
#       5     if np.mod(i, 3) == 0:
#       6         # Sometimes you need to relaunch TORCS because of the memory leak error
# ----> 7         ob = env.reset(relaunch=True)
#       8     else:
#       9         ob = env.reset()
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs_root/gym_torcs.py in reset(self, relaunch)
#     181
#     182         # Modify here if you use multiple tracks in the environment
# --> 183         self.client = snakeoil3.Client(p=3101, vision=self.vision)  # Open new UDP in vtorcs
#     184         self.client.MAX_STEPS = np.inf
#     185
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs_root/snakeoil3_gym.py in __init__(self, H, p, i, e, t, s, d, vision)
#     139         self.S= ServerState()
#     140         self.R= DriverAction()
# --> 141         self.setup_connection()
#     142
#     143     def setup_connection(self):
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs_root/snakeoil3_gym.py in setup_connection(self)
#     166             sockdata= str()
#     167             try:
# --> 168                 sockdata,addr= self.so.recvfrom(data_size)
#     169                 sockdata = sockdata.decode('utf-8')
#     170             except socket.error as emsg:
#
# KeyboardInterrupt:

# %%
# Out:
# python3: can't open file '../gym_torcs_root/example_experiemnt.py': [Errno 2] No such file or directory
