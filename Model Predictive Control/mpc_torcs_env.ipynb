# %%
#!pip3 install PyAutoGUI
#!sudo apt-get install scrot
#os.system('pkill torcs')

# %%
def laser_to_xy(sleft,sright,ang):
    X=sright*np.cos(ang)+sleft*np.cos(ang)
    X=X/2.0
    width=sright*np.sin(ang)+sleft*np.sin(angl)
    centreY=width/2.0
    Y=sright*np.sin(ang)-width
    return X,Y

# %%
import sys,os
sys.path.append("../gym_torcs-root/")
#from gym_torcs import TorcsEnv
from sample_agent import Agent
import numpy as np
from snakeoil_v1 import Client_v1,drive_example
import pyautogui as pg
import time
import pyautogui as pg
from matplotlib import pyplot as plt
import cv2
from collections import deque

# %%
# %matplotlib notebook
C= Client_v1(p=3101,vision=False,jupyter=True)
#img=np.ones((64,64,3),dtype=np.uint8)
#ims=plt.imshow(img)
#plt.show()

def init_plot():
    #fig = plt.figure(nro)
    fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(10,6))
    plt.ion()
    fig.show()
    return plt,fig,axes
plt,fig,axes=init_plot()
#axes.clear()
tc_q=deque(maxlen=10)
for i in range(1000):
#if 1==1:
        C.get_servers_input()
        time.sleep(.1)
        #print("got input ...")
        tc=C.S.d['track']
        #img1=np.array(img,dtype=np.uint8)
        #img1=img1.reshape(64,64,3)
        tcs=tc[0:5]+tc[-5:]
        tc_q.append(tcs)
        temp_q=np.array(tc_q)
        for ax1,ax2 in zip(axes[0],axes[1]):
            ax1.clear()
            ax2.clear()
        
        axes[0,0].plot(temp_q[:,:5])
        axes[1,0].plot(temp_q[:,-5:])
        
        fig.canvas.draw()
        
        print('plotted...',tc[0],tc[-1])
        #drive_example(C)
        C.R.d['steer']=steer
        C.R.d['gas']=gas
        C.respond_to_server()
plt.show()
#plt.show()






#plt.ioff()
#C.shutdown()
# Out:
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# ('127.0.0.1', 3101) ***identified***
# done
# <img src="data:image/png;base64,..." width="1000">
# plotted... 7.48438 7.94949
# plotted... 7.47823 7.9555
# plotted... 7.46982 7.96749
# plotted... 7.45446 7.97544
# plotted... 7.44224 7.97268
# plotted... 7.43431 7.98355
# plotted... 7.43177 7.9848
# plotted... 7.43129 7.98013
# plotted... 7.4349 7.96152
# plotted... 7.44403 7.93468
# plotted... 7.45839 7.90295
# plotted... 7.47736 7.86771
# plotted... 7.5015 7.82784
# plotted... 7.53476 7.78037
# plotted... 7.58995 7.70601
# plotted... 7.67824 7.59594
# plotted... 7.81821 7.4336
# plotted... 8.03236 7.20302
# plotted... 8.36486 6.86526
# plotted... 8.85955 6.3847
# plotted... 9.59406 5.7036
# plotted... 10.6376 4.78506
# plotted... 12.0253 3.60778
# plotted... 13.8045 2.17373
# plotted... 15.9794 0.500275
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... 15.4202 1.2205
# plotted... 13.7328 4.31662
# plotted... 11.5579 8.49262
# plotted... 8.95617 14.3586
# plotted... 5.66177 22.7715
# plotted... 1.43344 35.2972
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... -1.0 -1.0
# plotted... 4.9457 21.0554
# plotted... 4.15902 11.8756
# plotted... 4.95799 10.3397
# plotted... 5.78336 10.6072
# plotted... 6.03963 10.6105
# plotted... 6.03493 10.5891
# plotted... 6.00632 10.6901
# plotted... 5.96965 10.8357
# plotted... 5.92757 10.9915
# plotted... 5.87954 11.1697
# plotted... 5.82447 11.375
# plotted... 5.76773 11.6445
# plotted... 5.70887 11.9312
# plotted... 5.64733 12.2378
# plotted... 5.58302 12.5627
# plotted... 5.52054 12.9499
# plotted... 5.45655 13.3465
# plotted... 5.39296 13.7627
# plotted... 5.3294 14.1882
# plotted... 5.27007 14.6814
# plotted... 5.21111 15.1874
# plotted... 5.15277 15.7002
# plotted... 5.09483 16.2275
# plotted... 5.03863 16.7664
# plotted... 4.98268 17.3077
# plotted... 4.92712 17.8444
# plotted... 4.8736 18.3849
# plotted... 4.82232 18.9269
# plotted... 4.77204 19.453
# plotted... 4.72416 19.9785
# plotted... 4.67804 20.4865
# plotted... 4.63375 20.9561
# plotted... 4.59297 21.4141
# plotted... 4.55552 21.8417
# plotted... 4.52215 22.2522
# plotted... 4.49237 22.629
# plotted... 4.46605 22.9803
# plotted... 4.44219 23.2788
# plotted... 4.42233 23.5345
# plotted... 4.4064 23.7441
# plotted... 4.39484 23.9111
# plotted... 4.39046 24.0822
# plotted... 4.3864 24.1376
# plotted... 4.38667 24.1803
# plotted... 4.39047 24.2347
# plotted... 4.39282 24.2552
# plotted... 4.39228 24.2635
# plotted... 4.39286 24.2641
# plotted... 4.39377 24.2871
# plotted... 4.3948 24.2917
# plotted... 4.39579 24.3089
# plotted... 4.3948 24.2843
# plotted... 4.39688 24.3112
# plotted... 4.3969 24.3056
# plotted... 4.40026 24.343
# plotted... 4.40031 24.3522
# plotted... 4.39995 24.3395
# plotted... 4.40186 24.3644
# plotted... 4.40199 24.3652
# plotted... 4.40483 24.4108
# plotted... 4.40663 24.4492
# plotted... 4.40799 24.4637
# plotted... 4.40683 24.456
# plotted... 4.40681 24.4566
# plotted... 4.40866 24.4788
# plotted... 4.40883 24.4847
# plotted... 4.40738 24.471
# plotted... 4.40848 24.4661
# plotted... 4.40978 24.4937
# plotted... 4.40885 24.4862
# plotted... 4.40774 24.4644
# plotted... 4.40805 24.4671
# plotted... 4.40784 24.4567
# plotted... 4.41079 24.5002
# plotted... 4.4096 24.4784
# plotted... 4.41216 24.4941
# plotted... 4.41215 24.4803
# plotted... 4.41242 24.4839
# plotted... 4.41053 24.4495
# plotted... 4.411 24.444
# plotted... 4.4108 24.4409
# plotted... 4.40923 24.4173
# plotted... 4.40945 24.4252
# plotted... 4.41016 24.4395
# plotted... 4.41105 24.4505
# plotted... 4.41085 24.4669
# plotted... 4.40834 24.4221
# plotted... 4.40785 24.416
# plotted... 4.4085 24.4223
# plotted... 4.40761 24.4043
# plotted... 4.4087 24.4034
# plotted... 4.40789 24.3963
# plotted... 4.40862 24.4096
# plotted... 4.40885 24.4203
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  ...
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  ...

# %%
vision = True
episode_count = 10
max_steps = 50
reward = 0
done = False
step = 0

# Generate a Torcs environment
env = TorcsEnv(vision=vision, throttle=False,jupyter=True)

agent = Agent(1)  # steering only


print("TORCS Experiment Start.")
for i in range(episode_count):
    print("Episode : " + str(i))

    if np.mod(i, 3) == 0:
        # Sometimes you need to relaunch TORCS because of the memory leak error
        ob = env.reset(relaunch=True)
    else:
        ob = env.reset()

    total_reward = 0.
    for j in range(max_steps):
        action = agent.act(ob, reward, done, vision)

        ob, reward, done, _ = env.step(action)
        #print(ob)
        total_reward += reward

        step += 1
        if done:
            break

    print("TOTAL REWARD @ " + str(i) +" -th Episode  :  " + str(total_reward))
    print("Total Step: " + str(step))
    print("")

env.end()  # This is for shutting down TORCS
print("Finish.")
# Out:
# TORCS Experiment Start.
# Episode : 0
# loop
# Waiting for server on 3101............
# Count Down : 5
# loop
# ('127.0.0.1', 3101) ***identified***
# Client connected on 3101..............
# done
# (31, 3)
# (31, 3)
# (32, 3)
# (31, 3)
# (32, 3)
# (29, 3)
# (31, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (29, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (31, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (37, 3)
# (42, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (42, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (42, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (43, 3)
# (42, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (42, 3)
# (35, 3)
# (32, 3)
# TOTAL REWARD @ 0 -th Episode  :  758.5256545746887
# Total Step: 50
#
# Episode : 1
# loop
# Waiting for server on 3101............
# Count Down : 5
# loop
# ('127.0.0.1', 3101) ***identified***
# Client connected on 3101..............
# done
# (31, 3)
# (30, 3)
# (30, 3)
# (31, 3)
# (31, 3)
# (30, 3)
# (31, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (33, 3)
# (34, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (31, 3)
# (33, 3)
# (37, 3)
# (37, 3)
# (41, 3)
# (43, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (42, 3)
# (43, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (42, 3)
# (42, 3)
# (42, 3)
# (43, 3)
# (40, 3)
# (43, 3)
# (43, 3)
# (42, 3)
# TOTAL REWARD @ 1 -th Episode  :  598.0022360650682
# Total Step: 100
#
# Episode : 2
# loop
# Waiting for server on 3101............
# Count Down : 5
# loop
# ('127.0.0.1', 3101) ***identified***
# Client connected on 3101..............
# done
# (31, 3)
# (31, 3)
# (31, 3)
# (31, 3)
# (32, 3)
# (29, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (30, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (32, 3)
# (34, 3)
# (41, 3)
# (43, 3)
# (43, 3)
# (43, 3)
# (42, 3)
# (40, 3)
# (43, 3)
# (43, 3)
# (42, 3)
# TOTAL REWARD @ 2 -th Episode  :  677.2401601313983
# Total Step: 150
#
# Episode : 3
# ### TORCS is RELAUNCHED ###
# loop
# Waiting for server on 3101............
# Count Down : 5
# loop
# Waiting for server on 3101............
# Count Down : 4
# loop
# Waiting for server on 3101............
# Count Down : 3
# loop
# Waiting for server on 3101............
# Count Down : 2
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# loop
# Waiting for server on 3101............
# Count Down : 4
# loop
# Waiting for server on 3101............
# Count Down : 3
# loop
# Waiting for server on 3101............
# Count Down : 2
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# loop
# Waiting for server on 3101............
# Count Down : 4
# loop
# Waiting for server on 3101............
# Count Down : 3
# loop
# Waiting for server on 3101............
# Count Down : 2
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# Waiting for server on 3101............
# Count Down : 0
# loop
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# loop
# Waiting for server on 3101............
# Count Down : 4
# loop
# Waiting for server on 3101............
# Count Down : 3
# loop
# Waiting for server on 3101............
# Count Down : 2
# loop
# Waiting for server on 3101............
# Count Down : 1
# loop
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-77d169c5902c> in <module>
#      18     if np.mod(i, 3) == 0:
#      19         # Sometimes you need to relaunch TORCS because of the memory leak error
# ---> 20         ob = env.reset(relaunch=True)
#      21     else:
#      22         ob = env.reset()
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/gym_torcs.py in reset(self, relaunch)
#     184
#     185         # Modify here if you use multiple tracks in the environment
# --> 186         self.client = snakeoil3.Client(p=3101, vision=self.vision,jupyter=self.jupyter)  # Open new UDP in vtorcs
#     187         self.client.MAX_STEPS = np.inf
#     188
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/snakeoil3_gym.py in __init__(self, H, p, i, e, t, s, d, vision, jupyter)
#     140         self.S= ServerState()
#     141         self.R= DriverAction()
# --> 142         self.setup_connection()
#     143         print("done")
#     144     def setup_connection(self):
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/snakeoil3_gym.py in setup_connection(self)
#     167             sockdata= str()
#     168             try:
# --> 169                 sockdata,addr= self.so.recvfrom(data_size)
#     170                 sockdata = sockdata.decode('utf-8')
#     171                 print(addr,sockdata)
#
# KeyboardInterrupt:

# %%
env = TorcsEnv(vision=True, throttle=False,jupyter=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-87e31126fcc1> in <module>
# ----> 1 env = TorcsEnv(vision=True, throttle=False,jupyter=True)
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/gym_torcs.py in __init__(self, vision, throttle, gear_change, jupyter)
#      37             os.system('sh autostart.sh')
#      38         else:
# ---> 39             start()
#      40         time.sleep(0.5)
#      41
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs-root/st.py in start()
#       2 import time
#       3 def start():
# ----> 4     os.system('pkill torcs')
#       5     os.system('torcs -nofuel -nodamage -nolaptime -vision &')
#       6     time.sleep(1)
#
# NameError: name 'os' is not defined

# %%
vision = True
episode_count = 10
max_steps = 50
reward = 0
done = False
step = 0

# Generate a Torcs environment
env = TorcsEnv(vision=vision, throttle=False)

agent = Agent(1)  # steering only

# %%
ob = env.reset(relaunch=True)
ob

# %%
ob
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6b700ec508d9> in <module>
# ----> 1 ob
#
# NameError: name 'ob' is not defined

# %%
print("TORCS Experiment Start.")
for i in range(episode_count):
    print("Episode : " + str(i))

    if np.mod(i, 3) == 0:
        # Sometimes you need to relaunch TORCS because of the memory leak error
        ob = env.reset(relaunch=True)
    else:
        ob = env.reset()

    total_reward = 0.
    for j in range(max_steps):
        action = agent.act(ob, reward, done, vision)

        ob, reward, done, _ = env.step(action)
        #print(ob)
        total_reward += reward

        step += 1
        if done:
            break

    print("TOTAL REWARD @ " + str(i) +" -th Episode  :  " + str(total_reward))
    print("Total Step: " + str(step))
    print("")

env.end()  # This is for shutting down TORCS
print("Finish.")
# Out:
# TORCS Experiment Start.
# Episode : 0
# Waiting for server on 3101............
# Count Down : 5
# Waiting for server on 3101............
# Count Down : 4
# Waiting for server on 3101............
# Count Down : 3
# Waiting for server on 3101............
# Count Down : 2
# Waiting for server on 3101............
# Count Down : 1
# Waiting for server on 3101............
# Count Down : 0
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# Waiting for server on 3101............
# Count Down : 4
# Waiting for server on 3101............
# Count Down : 3
# Waiting for server on 3101............
# Count Down : 2
# Waiting for server on 3101............
# Count Down : 1
# Waiting for server on 3101............
# Count Down : 0
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# Waiting for server on 3101............
# Count Down : 4
# Waiting for server on 3101............
# Count Down : 3
# Waiting for server on 3101............
# Count Down : 2
# Waiting for server on 3101............
# Count Down : 1
# Waiting for server on 3101............
# Count Down : 0
# Waiting for server on 3101............
# Count Down : -1
# relaunch torcs
# Waiting for server on 3101............
# Count Down : 4
# Waiting for server on 3101............
# Count Down : 3
# Waiting for server on 3101............
# Count Down : 2
# Waiting for server on 3101............
# Count Down : 1
# Waiting for server on 3101............
# Count Down : 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ed10df93e941> in <module>
#       5     if np.mod(i, 3) == 0:
#       6         # Sometimes you need to relaunch TORCS because of the memory leak error
# ----> 7         ob = env.reset(relaunch=True)
#       8     else:
#       9         ob = env.reset()
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs_root/gym_torcs.py in reset(self, relaunch)
#     181
#     182         # Modify here if you use multiple tracks in the environment
# --> 183         self.client = snakeoil3.Client(p=3101, vision=self.vision)  # Open new UDP in vtorcs
#     184         self.client.MAX_STEPS = np.inf
#     185
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs_root/snakeoil3_gym.py in __init__(self, H, p, i, e, t, s, d, vision)
#     139         self.S= ServerState()
#     140         self.R= DriverAction()
# --> 141         self.setup_connection()
#     142
#     143     def setup_connection(self):
#
# ~/Desktop/PythonRobotics/Control-algorithms/gym_torcs_root/snakeoil3_gym.py in setup_connection(self)
#     166             sockdata= str()
#     167             try:
# --> 168                 sockdata,addr= self.so.recvfrom(data_size)
#     169                 sockdata = sockdata.decode('utf-8')
#     170             except socket.error as emsg:
#
# KeyboardInterrupt:

# %%
# Out:
# python3: can't open file '../gym_torcs_root/example_experiemnt.py': [Errno 2] No such file or directory
